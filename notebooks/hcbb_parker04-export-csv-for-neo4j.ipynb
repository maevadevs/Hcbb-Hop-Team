# %%
import pandas as pd
import sqlite3
from tqdm.notebook import tqdm # Provides progress bar for long tasks

# %%
pd.set_option("display.max_columns", 500)

# %% [markdown]
# ### Listing currently existing tables in the database

# %%
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT name
    FROM sqlite_master 
    WHERE type ='table' 
    AND name NOT LIKE 'sqlite_%';
    """ 
    
    db_table_list = pd.read_sql(query, db)

display(db_table_list)
# Out:
#                    name
# 0              taxonomy
# 1           hop_teaming
# 2               npidata
# 3  filtered_hop_teaming

# %% [markdown]
# ### `providers.csv`

# %% [markdown]
# Exported from SQL-Lite `npidata` with applied filters: `entity_type_code == 1`

# %%
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT *
    FROM npidata
    WHERE entity_type_code = 1;
    """ 
    
    providers = pd.read_sql(query, db)

display(providers.shape)
display(providers)
# Out:
# (32949, 16)
#               npi entity_type_code provider_org_name provider_last_name  \
# 0      1134122187                1              None           RUDNICKE
# 1      1003819046                1              None           NYLANDER
# 2      1750384780                1              None           PERRIGIN
# 3      1922001957                1              None            PRESLEY
# 4      1073516001                1              None               ROSS
# ...           ...              ...               ...                ...
# 32944  1477145944                1              None               HILL
# 32945  1447842935                1              None          CLEVELAND
# 32946  1639761190                1              None              ARNDT
# 32947  1588256051                1              None               WRAY
# 32948  1134711625                1              None             GRIMES
#
#       provider_first_name provider_middle_name provider_name_prefix  \
# 0                  CHERYL               DENISE                 MRS.
# 1                 BARBARA                    H                 None
# 2                   JULIE                    A                  DR.
# 3                 RICHARD                    E                 None
# 4                   DAVID                    L                  DR.
# ...                   ...                  ...                  ...
# 32944           DOMINIQUE             DANIELLE                 MRS.
# 32945            MEREDITH                    B                 MRS.
# 32946            VERONICA                  LEE                 None
# 32947                DAWN             MICHELLE                 None
# 32948           MACKENZIE                ELISE                 None
#
#       provider_name_suffix provider_credential  \
# 0                     None                CRNP
# 1                     None                M.D.
# 2                     None                  MD
# 3                     None                M.D.
# 4                     None                  MD
# ...                    ...                 ...
# 32944                 None          M.ED., LPC
# 32945                 None        MA, LPC-MHSP
# 32946                 None                  NP
# 32947                 None    MSN, APRN, FNP-C
# 32948                 None                None
#
#             provider_business_address_1 provider_business_address_2  \
# 0                        250 25TH AVE N                     STE 412
# 1                        345 23RD AVE N                   SUITE 209
# 2                         219 CHURCH ST                        None
# 3                       2011 MURPHY AVE                     STE 302
# 4                 127 CRESTVIEW PARK DR                        None
# ...                                 ...                         ...
# 32944                  1712 BISCAYNE DR                        None
# 32945         5205 MARYLAND WAY STE 310                        None
# 32946  30 HAMILTON STATION XING APT 104                        None
# 32947         3712 OLD CLARKSVILLE PIKE                        None
# 32948                  331 RIVERBEND DR                        None
#
#       provider_business_city provider_business_state provider_business_zip  \
# 0                  NASHVILLE                      TN             372031632
# 1                  NASHVILLE                      TN             372031513
# 2                    DICKSON                      TN             370551303
# 3                  NASHVILLE                      TN             372032023
# 4                    DICKSON                      TN             370552850
# ...                      ...                     ...                   ...
# 32944               FRANKLIN                      TN             370671475
# 32945              BRENTWOOD                      TN             370271049
# 32946                LEBANON                      TN             370879017
# 32947                JOELTON                      TN             370808818
# 32948               FRANKLIN                      TN             370645550
#
#       taxonomy_code provider_business_zip5
# 0        363L00000X                  37203
# 1        207VG0400X                  37203
# 2        207Q00000X                  37055
# 3        207V00000X                  37203
# 4        207R00000X                  37055
# ...             ...                    ...
# 32944    101YP2500X                  37067
# 32945    101YM0800X                  37027
# 32946    163W00000X                  37087
# 32947    363LF0000X                  37080
# 32948    2084P0800X                  37064
#
# [32949 rows x 16 columns]

# %% [markdown]
# ### `facilities.csv`

# %% [markdown]
# Exported from SQL-Lite `npidata` with applied filters: `entity_type_code == 2`

# %%
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT *
    FROM npidata
    WHERE entity_type_code = 2;
    """ 
    
    facilities = pd.read_sql(query, db)

display(facilities.shape)
display(facilities.head())
# Out:
# (8359, 16)
#           npi entity_type_code                  provider_org_name  \
# 0  1881697092                2                          RHS, INC.
# 1  1326041534                2  MURFREESBORO CONVALESCENT SERVICE
# 2  1063415834                2         ADVANCED DIABETIC SERVICES
# 3  1538162334                2     TENNESSEE IMAGING ALLIANCE LLC
# 4  1245233220                2      NORTHRIDGE SURGERY CENTER, LP
#
#   provider_last_name provider_first_name provider_middle_name  \
# 0               None                None                 None
# 1               None                None                 None
# 2               None                None                 None
# 3               None                None                 None
# 4               None                None                 None
#
#   provider_name_prefix provider_name_suffix provider_credential  \
# 0                 None                 None                None
# 1                 None                 None                None
# 2                 None                 None                None
# 3                 None                 None                None
# 4                 None                 None                None
#
#   provider_business_address_1 provider_business_address_2  \
# 0           1330 TROTWOOD AVE                        None
# 1         4428 LASCASSAS PIKE                        None
# 2        151 HERITAGE PARK DR                     STE 403
# 3      2628 N MOUNT JULIET RD                        None
# 4                647 MYATT DR                        None
#
#   provider_business_city provider_business_state provider_business_zip  \
# 0               COLUMBIA                      TN             384014701
# 1           MURFREESBORO                      TN             371306871
# 2           MURFREESBORO                      TN             371290505
# 3           MOUNT JULIET                      TN             371228015
# 4                MADISON                      TN             371152125
#
#   taxonomy_code provider_business_zip5
# 0    332B00000X                  38401
# 1    341600000X                  37130
# 2    332B00000X                  37129
# 3    261QR0208X                  37122
# 4    261QA1903X                  37115

# %% [markdown]
# ### `filtered_hop_teaming.csv`

# %% [markdown]
# Exported from SQL-Lite `filtered_hop_teaming`

# %%
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT *
    FROM filtered_hop_teaming;
    """ 
    
    filtered_hop_teaming = pd.read_sql(query, db)

display(filtered_hop_teaming.shape)
display(filtered_hop_teaming.head())
# Out:
# (44299, 6)
#      from_npi      to_npi  patient_count  transaction_count  average_day_wait  \
# 0  1003963976  1003028770           2535               3945             0.000
# 1  1033191986  1003052697            196                300            38.877
# 2  1023019429  1003052697             42                 61            25.607
# 3  1003854258  1003052697             31                 55            20.436
# 4  1033246640  1003863580             58                 58            45.603
#
#    std_day_wait
# 0         0.000
# 1        35.767
# 2        40.824
# 3        26.403
# 4        56.574

# %% [markdown]
# ### `specializations.csv`

# %% [markdown]
# Exported from SQL-Lite `taxonomy` with only `taxonomy_code` and non-null `specializations`

# %%
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT 
        taxonomy_code, 
        specialization
    FROM taxonomy
    WHERE specialization IS NOT NULL;
    """ 
    
    specializations = pd.read_sql(query, db)

display(specializations.shape)
display(specializations.head())
# Out:
# (625, 2)
#   taxonomy_code                    specialization
# 0    207KA0200X                           Allergy
# 1    207KI0005X  Clinical & Laboratory Immunology
# 2    207LA0401X                Addiction Medicine
# 3    207LC0200X            Critical Care Medicine
# 4    207LH0002X   Hospice and Palliative Medicine

# %% [markdown]
# ### `classifications.csv`

# %% [markdown]
# Exported from SQL-Lite `taxonomy` with only `taxonomy_code` and non-null `classifications`

# %%
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT 
        taxonomy_code, 
        classification
    FROM taxonomy
    WHERE classification IS NOT NULL;
    """ 
    
    classifications = pd.read_sql(query, db)

display(classifications.shape)
display(classifications.head())
# Out:
# (865, 2)
#   taxonomy_code        classification
# 0    193200000X       Multi-Specialty
# 1    193400000X      Single Specialty
# 2    207K00000X  Allergy & Immunology
# 3    207KA0200X  Allergy & Immunology
# 4    207KI0005X  Allergy & Immunology

# %% [markdown]
# ### `groupings.csv`

# %% [markdown]
# Exported from SQL-Lite `taxonomy` with only `taxonomy_code` and non-null `groupings`

# %%
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT 
        taxonomy_code, 
        grouping
    FROM taxonomy
    WHERE grouping IS NOT NULL;
    """ 
    
    groupings = pd.read_sql(query, db)

display(groupings.shape)
display(groupings.head())
# Out:
# (865, 2)
#   taxonomy_code                             grouping
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians

# %% [markdown]
# ### Export all to CSV

# %%
providers.to_csv("../neo4j_imports/providers.csv", index=False)

# %%
facilities.to_csv("../neo4j_imports/facilities.csv", index=False)

# %%
filtered_hop_teaming.to_csv("../neo4j_imports/filtered_hop_teaming.csv", index=False)

# %%
specializations.to_csv("../neo4j_imports/specializations.csv", index=False)

# %%
classifications.to_csv("../neo4j_imports/classifications.csv", index=False)

# %%
groupings.to_csv("../neo4j_imports/groupings.csv", index=False)
