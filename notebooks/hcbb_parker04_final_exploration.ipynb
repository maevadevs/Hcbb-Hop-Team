# %%
import pandas as pd
import sqlite3
from tqdm.notebook import tqdm
import plotly.express as px
import numpy as np
import plotly.graph_objects as go

# %%
pd.set_option("display.max_columns", 500)

# %%
#Listing currently existing tables in the database
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        SELECT name
        FROM sqlite_master 
        WHERE type ='table' 
        AND name NOT LIKE 'sqlite_%';
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#                    name
# 0              taxonomy
# 1           hop_teaming
# 2                  cbsa
# 3               npidata
# 4     npidata_nashville
# 5  filtered_hop_teaming
# 6             hospitals
# 7             referrals

# %%
#See number of rows
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        SELECT COUNT(DISTINCT from_npi)
        From referrals
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#    COUNT(DISTINCT from_npi)
# 0                      4225

# %%
#See first row
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        SELECT *
        From referrals
        LIMIT 1
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#    Unnamed: 0   index    from_npi      to_npi  patient_count  \
# 0           0  615039  1013179860  1417938846             71
#
#    transaction_count  average_day_wait  std_day_wait  from_zip  \
# 0                 82            35.049        42.548     37075
#
#   from_npi_specialty  from_entity_type_code  to_zip  \
# 0  Internal Medicine                    1.0   37083
#
#               to_npi_specialty  to_entity_type_code  \
# 0  General Acute Care Hospital                  2.0
#
#                            to_facility              to_facility_group  \
# 0  MACON COUNTY GENERAL HOSPITAL, INC.  Macon County General Hospital
#
#      to_facility_name_normalised
# 0  Macon County General Hospital

# %% [markdown]
# ## Look at Facility Groups, Classifications, and Specializations

# %%
# Look at facility groups
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        SELECT DISTINCT(to_facility_group)
        FROM referrals
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#                        to_facility_group
# 0          Macon County General Hospital
# 1          Maury Regional Medical Center
# 2                                    HCA
# 3                 Ascension Saint Thomas
# 4   Vanderbilt University Medical Center
# 5              Williamson Medical Center
# 6              NorthCrest Medical Center
# 7             Nashville General Hosptial
# 8         Sumner Regional Medical Center
# 9      Riverview Regional Medical Center
# 10              Trousdale Medical Center

# %%
# Look at categories
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        SELECT DISTINCT(from_npi_specialty), SUM(transaction_count)
        FROM referrals
        GROUP BY from_npi_specialty
        ORDER BY SUM(transaction_count) DESC
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#                                    from_npi_specialty  SUM(transaction_count)
# 0                                   Internal Medicine                  678099
# 1                                           Radiology                  397137
# 2                                  Nurse Practitioner                  121343
# 3                                     Family Medicine                  102980
# 4                                  Emergency Medicine                   81652
# 5                                           Pathology                   62149
# 6                                 Orthopaedic Surgery                   56882
# 7                                      Anesthesiology                   50313
# 8             Nurse Anesthetist, Certified Registered                   49618
# 9                                             Surgery                   42601
# 10                             Psychiatry & Neurology                   42267
# 11                                      Ophthalmology                   29442
# 12                                         Specialist                   28980
# 13                                            Urology                   28085
# 14                                Physician Assistant                   27559
# 15                                        Hospitalist                   21077
# 16                                     Otolaryngology                   18843
# 17                                         Podiatrist                   18364
# 18                 Physical Medicine & Rehabilitation                   10419
# 19                               Neurological Surgery                    9956
# 20                            Obstetrics & Gynecology                    9946
# 21                                        Dermatology                    8659
# 22  Thoracic Surgery (Cardiothoracic Vascular Surg...                    6650
# 23                                   General Practice                    4384
# 24                                      Pain Medicine                    4290
# 25                                   Nuclear Medicine                    3038
# 26                                 Physical Therapist                    2441
# 27                                         Pediatrics                    2418
# 28                               Allergy & Immunology                    2295
# 29                                    Plastic Surgery                    1784
# 30                                               None                    1533
# 31                                       Psychologist                    1508
# 32                                Preventive Medicine                    1503
# 33                                 Transplant Surgery                    1394
# 34                             Colon & Rectal Surgery                    1362
# 35                                       Chiropractor                    1207
# 36                          Clinical Nurse Specialist                     989
# 37                       Oral & Maxillofacial Surgery                     752
# 38                                        Optometrist                     690
# 39                                      Social Worker                     467
# 40  Student in an Organized Health Care Education/...                     458
# 41                         Clinical Neuropsychologist                     435
# 42                                   Registered Nurse                     331
# 43                              Clinical Pharmacology                     175
# 44                                          Counselor                     154
# 45                                     Legal Medicine                     107
# 46                         Anesthesiologist Assistant                      87
# 47                       Independent Medical Examiner                      58
# 48                                        Audiologist                      55

# %%
# Look at specializations
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        SELECT DISTINCT(taxonomy.specialization), SUM(referrals.transaction_count)
        FROM referrals
        JOIN npidata_nashville
            ON referrals.from_npi = npidata_nashville.npi
        JOIN taxonomy
            ON npidata_nashville.taxonomy_code = taxonomy.taxonomy_code
        GROUP BY taxonomy.specialization
        ORDER BY SUM(referrals.transaction_count) DESC
        LIMIT 20
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#                                       specialization  \
# 0                                               None
# 1                               Diagnostic Radiology
# 2                             Cardiovascular Disease
# 3            Anatomic Pathology & Clinical Pathology
# 4                                             Family
# 5                                         Nephrology
# 6                                  Pulmonary Disease
# 7                              Hematology & Oncology
# 8                                   Gastroenterology
# 9                                          Neurology
# 10                                  Medical Oncology
# 11                                        Acute Care
# 12                         Interventional Cardiology
# 13                Clinical Cardiac Electrophysiology
# 14                                      Rheumatology
# 15                                      Adult Health
# 16              Endocrinology, Diabetes & Metabolism
# 17                                  Vascular Surgery
# 18  Advanced Heart Failure and Transplant Cardiology
# 19                                Infectious Disease
#
#     SUM(referrals.transaction_count)
# 0                             723236
# 1                             372253
# 2                             176898
# 3                              52868
# 4                              52464
# 5                              50284
# 6                              42945
# 7                              39344
# 8                              31214
# 9                              28596
# 10                             28290
# 11                             27566
# 12                             23549
# 13                             20687
# 14                             16387
# 15                             14572
# 16                             13309
# 17                             12608
# 18                             11914
# 19                             11689

# %%
# Look at classifications and specializations together
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        SELECT taxonomy.classification, taxonomy.specialization, SUM(referrals.transaction_count)
        FROM referrals
        JOIN npidata_nashville
            ON referrals.from_npi = npidata_nashville.npi
        JOIN taxonomy
            ON npidata_nashville.taxonomy_code = taxonomy.taxonomy_code
        GROUP BY taxonomy.classification, taxonomy.specialization
        ORDER BY SUM(referrals.transaction_count) DESC
        LIMIT 50
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#                                        classification  \
# 0                                           Radiology
# 1                                   Internal Medicine
# 2                                   Internal Medicine
# 3                                     Family Medicine
# 4                                  Emergency Medicine
# 5                                           Pathology
# 6                                  Nurse Practitioner
# 7                                   Internal Medicine
# 8             Nurse Anesthetist, Certified Registered
# 9                                   Internal Medicine
# 10                                     Anesthesiology
# 11                                  Internal Medicine
# 12                                Orthopaedic Surgery
# 13                                  Internal Medicine
# 14                                         Specialist
# 15                             Psychiatry & Neurology
# 16                                  Internal Medicine
# 17                                            Urology
# 18                                 Nurse Practitioner
# 19                                  Internal Medicine
# 20                                            Surgery
# 21                                      Ophthalmology
# 22                                        Hospitalist
# 23                                  Internal Medicine
# 24                                Physician Assistant
# 25                                     Otolaryngology
# 26                                  Internal Medicine
# 27                                 Nurse Practitioner
# 28                                 Nurse Practitioner
# 29                                  Internal Medicine
# 30                                            Surgery
# 31                                  Internal Medicine
# 32                                  Internal Medicine
# 33                             Psychiatry & Neurology
# 34                               Neurological Surgery
# 35                                         Podiatrist
# 36                                          Radiology
# 37                                          Radiology
# 38                 Physical Medicine & Rehabilitation
# 39                                         Podiatrist
# 40                                     Anesthesiology
# 41                                 Emergency Medicine
# 42  Thoracic Surgery (Cardiothoracic Vascular Surg...
# 43                                        Dermatology
# 44                                  Internal Medicine
# 45                                          Radiology
# 46                                Physician Assistant
# 47                                  Internal Medicine
# 48                                Orthopaedic Surgery
# 49                                Orthopaedic Surgery
#
#                                       specialization  \
# 0                               Diagnostic Radiology
# 1                                               None
# 2                             Cardiovascular Disease
# 3                                               None
# 4                                               None
# 5            Anatomic Pathology & Clinical Pathology
# 6                                             Family
# 7                                         Nephrology
# 8                                               None
# 9                                  Pulmonary Disease
# 10                                              None
# 11                             Hematology & Oncology
# 12                                              None
# 13                                  Gastroenterology
# 14                                              None
# 15                                         Neurology
# 16                                  Medical Oncology
# 17                                              None
# 18                                        Acute Care
# 19                         Interventional Cardiology
# 20                                              None
# 21                                              None
# 22                                              None
# 23                Clinical Cardiac Electrophysiology
# 24                                              None
# 25                                              None
# 26                                      Rheumatology
# 27                                              None
# 28                                      Adult Health
# 29              Endocrinology, Diabetes & Metabolism
# 30                                  Vascular Surgery
# 31  Advanced Heart Failure and Transplant Cardiology
# 32                                Infectious Disease
# 33                                        Psychiatry
# 34                                              None
# 35                              Foot & Ankle Surgery
# 36                                Radiation Oncology
# 37               Vascular & Interventional Radiology
# 38                                              None
# 39                                              None
# 40                            Critical Care Medicine
# 41                        Emergency Medical Services
# 42                                              None
# 43                                              None
# 44                                Geriatric Medicine
# 45                                    Neuroradiology
# 46                                           Medical
# 47                                        Hematology
# 48                  Orthopaedic Surgery of the Spine
# 49          Adult Reconstructive Orthopaedic Surgery
#
#     SUM(referrals.transaction_count)
# 0                             372253
# 1                             190454
# 2                             176898
# 3                              97117
# 4                              73595
# 5                              52868
# 6                              52464
# 7                              50284
# 8                              49618
# 9                              42945
# 10                             40215
# 11                             39344
# 12                             34193
# 13                             31214
# 14                             28980
# 15                             28596
# 16                             28290
# 17                             27840
# 18                             27374
# 19                             23549
# 20                             23462
# 21                             23191
# 22                             21077
# 23                             20687
# 24                             17446
# 25                             16625
# 26                             16387
# 27                             15559
# 28                             14572
# 29                             13309
# 30                             12608
# 31                             11914
# 32                             11689
# 33                             10767
# 34                              9956
# 35                              9085
# 36                              8795
# 37                              7903
# 38                              7416
# 39                              7171
# 40                              7036
# 41                              6919
# 42                              6650
# 43                              6496
# 44                              6327
# 45                              6056
# 46                              5689
# 47                              5370
# 48                              5206
# 49                              5092

# %% [markdown]
# ## This is my starting code for NPI to Facility Groups

# %%
# Find count of NPIs sending to multiples of facility groups
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi, COUNT(DISTINCT to_facility_group) AS to_groups, SUM(transaction_count) AS npi_transactions
            FROM referrals
            GROUP BY from_npi
            ORDER BY to_groups DESC
        )
        SELECT *
        FROM CTE
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#         from_npi  to_groups  npi_transactions
# 0     1851677157          8              1176
# 1     1558355941          7              2574
# 2     1104933738          7              4570
# 3     1104837327          7              1522
# 4     1902823099          6              1336
# ...          ...        ...               ...
# 4220  1003063314          1               374
# 4221  1003050972          1               145
# 4222  1003031261          1               104
# 4223  1003019902          1               294
# 4224  1003013947          1               148
#
# [4225 rows x 3 columns]

# %%
# Find count of NPIs sending to multiples of facility groups
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi, COUNT(DISTINCT to_facility_group) AS to_groups, SUM(transaction_count) AS npi_transactions
            FROM referrals
            GROUP BY from_npi
            ORDER BY to_groups DESC
        )
        SELECT SUM(npi_transactions) AS total_transactions
        FROM CTE
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#    total_transactions
# 0             1936936

# %%
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        SELECT SUM(transaction_count) AS total_transactions
        FROM referrals
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#    total_transactions
# 0             1936936

# %%
# Crosscheck with random npi
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        SELECT *
        FROM referrals
        WHERE from_npi = '1851677157'
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#    Unnamed: 0     index    from_npi      to_npi  patient_count  \
# 0         167  13101574  1851677157  1861479545            229
# 1        1115  16079213  1851677157  1295780476             93
# 2        2290  15715727  1851677157  1023055126             72
# 3        3032  16034734  1851677157  1265445506             37
# 4        3697  16567504  1851677157  1669567897             94
# 5        5019  16213508  1851677157  1396882205             76
# 6        6228  16279847  1851677157  1447571658             96
# 7        6357  13186861  1851677157  1922319037             45
# 8        6411  16305736  1851677157  1467763458             39
#
#    transaction_count  average_day_wait  std_day_wait  from_zip  \
# 0                316            49.041        49.564     37083
# 1                158            36.753        45.089     37083
# 2                 90            47.956        41.384     37083
# 3                 65            33.985        35.362     37083
# 4                129            42.822        43.584     37083
# 5                 98            44.429        42.415     37083
# 6                163            35.350        39.862     37083
# 7                 64            31.047        31.309     37083
# 8                 93            18.280        21.475     37083
#
#    from_npi_specialty  from_entity_type_code  to_zip  \
# 0  Nurse Practitioner                    1.0   38401
# 1  Nurse Practitioner                    1.0   37207
# 2  Nurse Practitioner                    1.0   37203
# 3  Nurse Practitioner                    1.0   37067
# 4  Nurse Practitioner                    1.0   37172
# 5  Nurse Practitioner                    1.0   37232
# 6  Nurse Practitioner                    1.0   37066
# 7  Nurse Practitioner                    1.0   37030
# 8  Nurse Practitioner                    1.0   37074
#
#               to_npi_specialty  to_entity_type_code  \
# 0  General Acute Care Hospital                  2.0
# 1  General Acute Care Hospital                  2.0
# 2  General Acute Care Hospital                  2.0
# 3  General Acute Care Hospital                  2.0
# 4  General Acute Care Hospital                  2.0
# 5  General Acute Care Hospital                  2.0
# 6  General Acute Care Hospital                  2.0
# 7  General Acute Care Hospital                  2.0
# 8  General Acute Care Hospital                  2.0
#
#                               to_facility  \
# 0                 MAURY REGIONAL HOSPITAL
# 1       HTI MEMORIAL HOSPITAL CORPORATION
# 2  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 3     WILLIAMSON COUNTY HOSPITAL DISTRICT
# 4               NORTHCREST MEDICAL CENTER
# 5    VANDERBILT UNIVERSITY MEDICAL CENTER
# 6      SUMNER REGIONAL MEDICAL CENTER LLC
# 7            RIVERVIEW MEDICAL CENTER LLC
# 8            TROUSDALE MEDICAL CENTER LLC
#
#                       to_facility_group           to_facility_name_normalised
# 0         Maury Regional Medical Center         Maury Regional Medical Center
# 1                                   HCA    TriStar Skyline Medical Center HCA
# 2                                   HCA         Centennial Medical Center HCA
# 3             Williamson Medical Center            Williamson County Hospital
# 4             NorthCrest Medical Center             NorthCrest Medical Center
# 5  Vanderbilt University Medical Center  Vanderbilt University Medical Center
# 6        Sumner Regional Medical Center        Sumner Regional Medical Center
# 7     Riverview Regional Medical Center     Riverview Regional Medical Center
# 8              Trousdale Medical Center              Trousdale Medical Center

# %%
# Find count of NPIs sending to multiples of facility groups
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi, COUNT(DISTINCT to_facility_group) AS to_groups, SUM(transaction_count) AS npi_transactions
            FROM referrals
            GROUP BY from_npi
            ORDER BY to_groups DESC
        )
        SELECT to_groups, COUNT(to_groups) AS npis_per_count, SUM(npi_transactions) AS total_transactions
        FROM CTE
        GROUP BY to_groups
        ORDER BY to_groups DESC
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#    to_groups  npis_per_count  total_transactions
# 0          8               1                1176
# 1          7               3                8666
# 2          6               4                7075
# 3          5              20               32393
# 4          4              56              106690
# 5          3             199              217867
# 6          2             709              481393
# 7          1            3233             1081676

# %% [markdown]
# ## Narrow down to non-Vanderbilt Transactions

# %%
# Find count of NPIs sending to multiples of facility groups
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi, COUNT(DISTINCT to_facility_group) AS to_groups, SUM(transaction_count) AS npi_transactions
            FROM referrals
            WHERE to_facility_group <> 'Vanderbilt University Medical Center'
            GROUP BY from_npi
        )
        SELECT to_groups, COUNT(to_groups) AS npis_per_count, SUM(npi_transactions) AS total_transactions
        FROM CTE
        GROUP BY to_groups
        ORDER BY to_groups DESC
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#    to_groups  npis_per_count  total_transactions
# 0          7               1                1078
# 1          6               3                7014
# 2          5               5                8957
# 3          4              28               44792
# 4          3              61               78565
# 5          2             385              328801
# 6          1            2380              813604

# %%
# Find hospital groups with the largest number of single group, non-Vanderbilt NPIs
# Remove Radiology
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi
                , COUNT(DISTINCT to_facility_group) AS to_groups
                , SUM(transaction_count) AS npi_transactions
                , to_facility_group
            FROM referrals
            WHERE to_facility_group <> 'Vanderbilt University Medical Center'
            AND from_npi_specialty <> 'Radiology'
            GROUP BY from_npi
            HAVING to_groups = 1 AND npi_transactions >= 1000
        )
        SELECT CTE.to_facility_group, n.*, CTE.npi_transactions 
        FROM CTE
        INNER JOIN npidata_nashville AS n 
            ON CTE.from_npi = n.npi
        ORDER BY CTE.npi_transactions DESC
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#             to_facility_group         npi entity_type_code provider_org_name  \
# 0                         HCA  1053337717                1              None
# 1                         HCA  1427079946                1              None
# 2                         HCA  1114961513                1              None
# 3                         HCA  1730111642                1              None
# 4                         HCA  1245313741                1              None
# ..                        ...         ...              ...               ...
# 68     Ascension Saint Thomas  1407896749                1              None
# 69  NorthCrest Medical Center  1679557565                1              None
# 70                        HCA  1114020336                1              None
# 71  NorthCrest Medical Center  1033472592                1              None
# 72     Ascension Saint Thomas  1154534923                1              None
#
#    provider_last_name provider_first_name provider_middle_name  \
# 0                KAZA               SUNIL                    C
# 1              CONLEY         CHRISTOPHER                    N
# 2            HUMPHREY              STEVEN                    S
# 3               PATEL               TARAL         NAVINCHANDRA
# 4                LONG               BRIAN                    R
# ..                ...                 ...                  ...
# 68           CANONICO              ANGELO                   E.
# 69              CRUNK               TOMMY              HAMBLEN
# 70            KINGREE              RACHEL                MARIE
# 71              ANANI                LOVE                 None
# 72          ROBERTSON               PETER               GORDON
#
#    provider_name_prefix provider_name_suffix provider_credential  \
# 0                   DR.                 None                M.D.
# 1                   DR.                 None                M.D.
# 2                   DR.                 None                  MD
# 3                   DR.                 None                M.D.
# 4                   DR.                 None                  MD
# ..                  ...                  ...                 ...
# 68                 None                 None                M.D.
# 69                 None                 None                M.D.
# 70                  DR.                 None                M.D.
# 71                 None                 None                 M.D
# 72                  DR.                 None                  MD
#
#    provider_business_address_1 provider_business_address_2  \
# 0          3443 DICKERSON PIKE                   SUITE 430
# 1          3443 DICKERSON PIKE                   SUITE 430
# 2               395 WALLACE RD                  SUITE B300
# 3      5651 FRIST BLVD STE 603                        None
# 4   3601 THE VANDERBILT CLINIC                        None
# ..                         ...                         ...
# 68             4230 HARDING RD                   SUITE 400
# 69           224 NORTHCREST DR                        None
# 70             5651 FRIST BLVD                   SUITE 713
# 71           100 NORTHCREST DR                        None
# 72    1840 MEDICAL CENTER PKWY                   SUITE 201
#
#    provider_business_city provider_business_state provider_business_zip  \
# 0               NASHVILLE                      TN             372072519
# 1               NASHVILLE                      TN             372072519
# 2               NASHVILLE                      TN             372114881
# 3               HERMITAGE                      TN                 37076
# 4               NASHVILLE                      TN             372322519
# ..                    ...                     ...                   ...
# 68              NASHVILLE                      TN             372052013
# 69            SPRINGFIELD                      TN             371723962
# 70              HERMITAGE                      TN             370762054
# 71            SPRINGFIELD                      TN             371723927
# 72           MURFREESBORO                      TN             371292564
#
#    taxonomy_code provider_business_zip5    zip   cbsa  \
# 0     207RC0000X                  37207  37207  34980
# 1     207RC0001X                  37207  37207  34980
# 2     207RC0000X                  37211  37211  34980
# 3     207RI0011X                  37076  37076  34980
# 4     207RI0011X                  37232  37232  34980
# ..           ...                    ...    ...    ...
# 68    207RP1001X                  37205  37205  34980
# 69    207Q00000X                  37172  37172  34980
# 70    207RP1001X                  37076  37076  34980
# 71    207P00000X                  37172  37172  34980
# 72    207RC0001X                  37129  37129  34980
#
#                                grouping      classification  \
# 0   Allopathic & Osteopathic Physicians   Internal Medicine
# 1   Allopathic & Osteopathic Physicians   Internal Medicine
# 2   Allopathic & Osteopathic Physicians   Internal Medicine
# 3   Allopathic & Osteopathic Physicians   Internal Medicine
# 4   Allopathic & Osteopathic Physicians   Internal Medicine
# ..                                  ...                 ...
# 68  Allopathic & Osteopathic Physicians   Internal Medicine
# 69  Allopathic & Osteopathic Physicians     Family Medicine
# 70  Allopathic & Osteopathic Physicians   Internal Medicine
# 71  Allopathic & Osteopathic Physicians  Emergency Medicine
# 72  Allopathic & Osteopathic Physicians   Internal Medicine
#
#                         specialization  npi_transactions
# 0               Cardiovascular Disease              2320
# 1   Clinical Cardiac Electrophysiology              2233
# 2               Cardiovascular Disease              2166
# 3            Interventional Cardiology              2152
# 4            Interventional Cardiology              2018
# ..                                 ...               ...
# 68                   Pulmonary Disease              1041
# 69                                None              1040
# 70                   Pulmonary Disease              1019
# 71                                None              1011
# 72  Clinical Cardiac Electrophysiology              1001
#
# [73 rows x 23 columns]

# %%
# From below, summarize by Facility Group
# Find hospital groups with the largest number of single group, non-Vanderbilt NPIs
# Remove Radiology
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi
                , COUNT(DISTINCT to_facility_group) AS to_groups
                , SUM(transaction_count) AS npi_transactions
                , SUM(patient_count) AS npi_patients
                , to_facility_group
            FROM referrals
            WHERE to_facility_group <> 'Vanderbilt University Medical Center'
            AND from_npi_specialty NOT IN ('Radiology', 'Surgery', 'Emergency Medicine', 'Orthopaedic Surgery')
            GROUP BY from_npi
            HAVING to_groups = 1 AND npi_transactions >= 500
        ), CTE_2 AS(
            SELECT CTE.to_facility_group, n.*, CTE.npi_transactions, CTE.npi_patients
            FROM CTE
            INNER JOIN npidata_nashville AS n 
                ON CTE.from_npi = n.npi
            ORDER BY CTE.npi_transactions DESC
        )
        SELECT to_facility_group
            , classification
            , COUNT(to_facility_group) AS count_npis
            , SUM(npi_transactions) AS total_transactions
            , SUM(npi_transactions) / COUNT(to_facility_group) AS transactions_per_npi
            , SUM(npi_patients) AS total_patients
        FROM CTE_2
        GROUP BY to_facility_group, classification
        ORDER BY to_facility_group, SUM(npi_transactions) DESC 
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#                     to_facility_group           classification  count_npis  \
# 0              Ascension Saint Thomas        Internal Medicine          49
# 1              Ascension Saint Thomas               Specialist           5
# 2              Ascension Saint Thomas                Pathology           5
# 3              Ascension Saint Thomas           Anesthesiology           5
# 4              Ascension Saint Thomas       Nurse Practitioner           3
# 5              Ascension Saint Thomas          Family Medicine           2
# 6              Ascension Saint Thomas   Psychiatry & Neurology           2
# 7              Ascension Saint Thomas                  Urology           1
# 8              Ascension Saint Thomas              Hospitalist           1
# 9                                 HCA        Internal Medicine          86
# 10                                HCA          Family Medicine          14
# 11                                HCA                Pathology           6
# 12                                HCA              Hospitalist           5
# 13                                HCA       Nurse Practitioner           4
# 14                                HCA               Specialist           2
# 15                                HCA               Podiatrist           2
# 16                                HCA            Ophthalmology           1
# 17                                HCA   Psychiatry & Neurology           1
# 18                                HCA         General Practice           1
# 19                                HCA     Neurological Surgery           1
# 20                                HCA                  Urology           1
# 21                                HCA           Otolaryngology           1
# 22      Maury Regional Medical Center        Internal Medicine          26
# 23      Maury Regional Medical Center          Family Medicine           7
# 24      Maury Regional Medical Center               Specialist           4
# 25      Maury Regional Medical Center       Nurse Practitioner           3
# 26      Maury Regional Medical Center           Otolaryngology           2
# 27      Maury Regional Medical Center                  Urology           2
# 28      Maury Regional Medical Center           Anesthesiology           3
# 29      Maury Regional Medical Center         General Practice           1
# 30      Maury Regional Medical Center  Obstetrics & Gynecology           1
# 31      Maury Regional Medical Center              Hospitalist           1
# 32      Maury Regional Medical Center   Psychiatry & Neurology           1
# 33      Maury Regional Medical Center            Ophthalmology           1
# 34          NorthCrest Medical Center        Internal Medicine           2
# 35          NorthCrest Medical Center          Family Medicine           2
# 36          NorthCrest Medical Center               Podiatrist           1
# 37          NorthCrest Medical Center              Hospitalist           1
# 38  Riverview Regional Medical Center       Nurse Practitioner           1
# 39  Riverview Regional Medical Center          Family Medicine           1
# 40  Riverview Regional Medical Center        Internal Medicine           1
# 41     Sumner Regional Medical Center        Internal Medicine           9
# 42     Sumner Regional Medical Center                Pathology           1
# 43     Sumner Regional Medical Center          Family Medicine           1
# 44          Williamson Medical Center        Internal Medicine          11
# 45          Williamson Medical Center          Family Medicine           4
# 46          Williamson Medical Center               Specialist           3
# 47          Williamson Medical Center                  Urology           3
# 48          Williamson Medical Center              Hospitalist           1
# 49          Williamson Medical Center       Nurse Practitioner           1
# 50          Williamson Medical Center                Pathology           1
#
#     total_transactions  transactions_per_npi  total_patients
# 0                42746                   872           32572
# 1                 3941                   788            3656
# 2                 3196                   639            3044
# 3                 2936                   587            2734
# 4                 1683                   561            1523
# 5                 1333                   666             832
# 6                 1146                   573            1049
# 7                  702                   702             403
# 8                  509                   509             487
# 9                80654                   937           52784
# 10                9956                   711            4845
# 11                4909                   818            4382
# 12                3424                   684            2631
# 13                3036                   759            1864
# 14                1506                   753            1025
# 15                1136                   568             613
# 16                 653                   653             379
# 17                 619                   619             505
# 18                 599                   599             556
# 19                 562                   562             415
# 20                 529                   529             321
# 21                 525                   525             388
# 22               24306                   934           16296
# 23                5529                   789            3308
# 24                4216                  1054            2331
# 25                2251                   750            1636
# 26                2203                  1101            1579
# 27                2036                  1018            1165
# 28                1839                   613            1649
# 29                 720                   720             175
# 30                 640                   640             499
# 31                 557                   557             486
# 32                 548                   548             346
# 33                 502                   502             312
# 34                1937                   968             820
# 35                1602                   801             585
# 36                 772                   772             346
# 37                 627                   627             493
# 38                 888                   888             225
# 39                 785                   785             201
# 40                 623                   623             112
# 41                6059                   673            4408
# 42                 871                   871             779
# 43                 534                   534             280
# 44               12559                  1141            8638
# 45                3214                   803            1324
# 46                2601                   867            2352
# 47                1914                   638            1272
# 48                 716                   716             558
# 49                 519                   519             467
# 50                 500                   500             464

# %% [markdown]
# ## Create Visual of NPIs to Poach

# %%
# From below, summarize by Facility Group
# Find hospital groups with the largest number of single group, non-Vanderbilt NPIs
# Remove Radiology
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi
                , COUNT(DISTINCT to_facility_group) AS to_groups
                , SUM(transaction_count) AS npi_transactions
                , SUM(patient_count) AS npi_patients
                , to_facility_group
            FROM referrals
            WHERE to_facility_group <> 'Vanderbilt University Medical Center'
            AND from_npi_specialty NOT IN ('Radiology', 'Emergency Medicine', 'Orthopaedic Surgery',
                                            'Pathology', 'Anesthesiology')
            GROUP BY from_npi
            HAVING to_groups = 1 AND npi_transactions >= 500
        ), CTE_2 AS(
            SELECT CTE.to_facility_group, CTE.npi_transactions, CTE.npi_patients, n.*
            FROM CTE
            INNER JOIN npidata_nashville AS n 
                ON CTE.from_npi = n.npi
            ORDER BY CTE.npi_transactions DESC
        )
        SELECT to_facility_group AS Facility_Group
            , npi
            , provider_first_name || ' ' || provider_last_name AS Name
            , classification AS Classification
            , COALESCE(specialization, 'None') AS Specialization
            , npi_transactions AS NPI_Transactions
            , npi_patients AS NPI_Patients
            , provider_business_address_1
            , provider_business_address_2
            , provider_business_city
            , provider_business_state
            , provider_business_zip5
        FROM CTE_2
        ORDER BY to_facility_group
        """ 

    poach = pd.read_sql(query, db)

display(poach)
# Out:
#                 Facility_Group         npi              Name  \
# 0       Ascension Saint Thomas  1770519704      DAVID GIBSON
# 1       Ascension Saint Thomas  1720241185  WARREN STRIBLING
# 2       Ascension Saint Thomas  1598719536       DON CHOMSKY
# 3       Ascension Saint Thomas  1457317257        GUY MIOTON
# 4       Ascension Saint Thomas  1942429816     ANDREW ZURICK
# ..                         ...         ...               ...
# 279  Williamson Medical Center  1346397130       PAUL FLESER
# 280  Williamson Medical Center  1952771941   JAYANTHI SAMUEL
# 281  Williamson Medical Center  1033246640     OUIDA COLLINS
# 282  Williamson Medical Center  1063864775        PAULA DUNN
# 283  Williamson Medical Center  1497721526       JOHN HASSAN
#
#          Classification                                    Specialization  \
# 0     Internal Medicine                            Cardiovascular Disease
# 1     Internal Medicine  Advanced Heart Failure and Transplant Cardiology
# 2     Internal Medicine                            Cardiovascular Disease
# 3     Internal Medicine                            Cardiovascular Disease
# 4     Internal Medicine                            Cardiovascular Disease
# ..                  ...                                               ...
# 279             Surgery                                  Vascular Surgery
# 280  Nurse Practitioner                                            Family
# 281     Family Medicine                                              None
# 282     Family Medicine                                              None
# 283             Urology                                              None
#
#      NPI_Transactions  NPI_Patients provider_business_address_1  \
# 0                1648          1454             4230 HARDING RD
# 1                1648           711            4230 HARDING RD.
# 2                1621           701             4230 HARDING RD
# 3                1458          1155    1840 MEDICAL CENTER PKWY
# 4                1421          1265            4230 HARDING RD.
# ..                ...           ...                         ...
# 279               570           330                100 COVEY DR
# 280               519           467         4323 CAROTHERS PKWY
# 281               510           407                    3601 TVC
# 282               504           237             4091 MALLORY LN
# 283               503           348           1909 MALLORY LANE
#
#     provider_business_address_2 provider_business_city  \
# 0                     SUITE 330              NASHVILLE
# 1                      STE. 330              NASHVILLE
# 2                     SUITE 330              NASHVILLE
# 3                     SUITE 201           MURFREESBORO
# 4                     SUITE 330              NASHVILLE
# ..                          ...                    ...
# 279                   SUITE 204               FRANKLIN
# 280                   SUITE 205               FRANKLIN
# 281                        None              NASHVILLE
# 282                        None               FRANKLIN
# 283                   SUITE 110               FRANKLIN
#
#     provider_business_state provider_business_zip5
# 0                        TN                  37205
# 1                        TN                  37205
# 2                        TN                  37205
# 3                        TN                  37129
# 4                        TN                  37205
# ..                      ...                    ...
# 279                      TN                  37067
# 280                      TN                  37067
# 281                      TN                  37232
# 282                      TN                  37067
# 283                      TN                  37067
#
# [284 rows x 12 columns]

# %%
fig = px.treemap(poach, path=['Facility_Group', 'Classification', 'Name'], values='NPI_Transactions',
                color='NPI_Patients', 
                hover_data=['Name', 'Classification', 'Specialization', 'provider_business_address_1',
                           'provider_business_address_2', 'provider_business_city',
                           'provider_business_state', 'provider_business_zip5'],
                color_continuous_scale='Emrld')
fig.show()
fig.write_html("/Users/mattparker/Documents/nss_projects/hcbb_hop_team-3m/notebooks/poaching_plotly.html")
# Out:
# <div>                            <div id="9f3b0239-e38a-4a07-b09b-0b7a71c49f86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f3b0239-e38a-4a07-b09b-0b7a71c49f86")) {                    Plotly.newPlot(                        "9f3b0239-e38a-4a07-b09b-0b7a71c49f86",                        [{"branchvalues": "total", "customdata": [["AARON MILSTONE", "Internal Medicine", "Pulmonary Disease", "4323 CAROTHERS PKWY", "SUITE 605", "FRANKLIN", "TN", "37067", 665.0], ["AARON PORTER", "Ophthalmology", "None", "3252 ASPEN GROVE DRIVE", "SUITE 1", "FRANKLIN", "TN", "37067", 379.0], ["ABU FAKHRUDDIN", "Internal Medicine", "Gastroenterology", "330 23RD AVE N", "SUITE 300", "NASHVILLE", "TN", "37203", 573.0], ["ADAM PRUDOFF", "Internal Medicine", "Cardiovascular Disease", "3601 TVC", null, "NASHVILLE", "TN", "37232", 1208.0], ["AHMAD ABU-HALIMAH", "Internal Medicine", "Cardiovascular Disease", "VANDERBILT UNIVERSITY MEDICAL CTR. CARDIOLOGY DIVISION.", "383 PRB, 2220 PIERCE AVE.", "NASHVILLE", "TN", "37232", 487.0], ["ALBERTO GONZALEZ-BERNAL", "Internal Medicine", "Critical Care Medicine", "3443 DICKERSON PK", "SUITE 680", "NASHVILLE", "TN", "37207", 759.0], ["AMANDA DANIEL", "Internal Medicine", "Endocrinology, Diabetes & Metabolism", "330 23RD AVE N", "SUITE 500", "NASHVILLE", "TN", "37203", 283.0], ["AMIT CHOKSI", "Internal Medicine", "Gastroenterology", "1222 TROTWOOD AVENUE", "STE 501", "COLUMBIA", "TN", "38401", 1271.0], ["AMIT KESWANI", "Internal Medicine", "Cardiovascular Disease", "3601 THE VANDERBILT CLINIC", null, "NASHVILLE", "TN", "37232", 722.0], ["AMIT SINGH", "Internal Medicine", "None", "300 STONECREST BLVD STE 110", null, "SMYRNA", "TN", "37167", 651.0], ["ANDREA BECK", "Internal Medicine", "None", "2400 PATTERSON ST", "SUITE 400", "NASHVILLE", "TN", "37203", 252.0], ["ANDREW GOODMAN", "Internal Medicine", "Interventional Cardiology", "2400 PATTERSON ST STE 502", null, "NASHVILLE", "TN", "37203", 396.0], ["ANDREW MCRAE", "Internal Medicine", "Advanced Heart Failure and Transplant Cardiology", "2400 PATTERSON ST", "SUITE 502", "NASHVILLE", "TN", "37203", 813.0], ["ANDREW MCVIE", "Specialist", "None", "4220 HARDING RD", null, "NASHVILLE", "TN", "37205", 795.0], ["ANDREW SAGER", "Internal Medicine", "Cardiovascular Disease", "222 22ND AVE N", "STE 400", "NASHVILLE", "TN", "37203", 468.0], ["ANDREW ZURICK", "Internal Medicine", "Cardiovascular Disease", "4230 HARDING RD.", "SUITE 330", "NASHVILLE", "TN", "37205", 1265.0], ["ANGELO CANONICO", "Internal Medicine", "Pulmonary Disease", "4230 HARDING RD", "SUITE 400", "NASHVILLE", "TN", "37205", 861.0], ["ANNIS MARNEY", "Internal Medicine", "Endocrinology, Diabetes & Metabolism", "330 23RD AVE N", "SUITE 500", "NASHVILLE", "TN", "37203", 373.0], ["ANSEL ANDERSON", "Specialist", "None", "4220 HARDING RD", null, "NASHVILLE", "TN", "37205", 834.0], ["ANTHONY KHIM", "Specialist", "None", "101 BERRYWOOD DR", null, "COLUMBIA", "TN", "38401", 649.0], ["ARNEL PANELO", "Hospitalist", "None", "2400 PATTERSON ST", "SUITE 311", "NASHVILLE", "TN", "37203", 410.0], ["ARTHUR CONSTANTINE", "Internal Medicine", "Cardiovascular Disease", "4230 HARDING PIKE", "SUITE 330", "NASHVILLE", "TN", "37205", 628.0], ["ASHLEY ROSE", "Internal Medicine", "None", "2300 PATTERSON ST", null, "NASHVILLE", "TN", "37203", 369.0], ["BARRETT CONNER", "Internal Medicine", "Pulmonary Disease", "3443 DICKERSON PIKE", "SUITE 680", "NASHVILLE", "TN", "37207", 650.0], ["BELINDA BART", "Family Medicine", "None", "1605 NASHVILLE HWY", "SUITE 200", "COLUMBIA", "TN", "38401", 596.0], ["BEN GARDNER", "Internal Medicine", "None", "854 W JAMES CAMPBELL BLVD", "SUITE 403", "COLUMBIA", "TN", "38401", 681.0], ["BENJAMIN DEHNER", "Urology", "None", "4230 HARDING RD", "SUITE 521", "NASHVILLE", "TN", " ...

# %% [markdown]
# # Alvin Request #1

# %%
fig_1 = px.treemap(poach, path=['Classification', 'Specialization', 'Name'], values='NPI_Patients',
                color='NPI_Patients', 
                hover_data=['Name', 'Classification', 'Specialization', 'provider_business_address_1',
                           'provider_business_address_2', 'provider_business_city',
                           'provider_business_state', 'provider_business_zip5'],
                color_continuous_scale='Emrld')
fig_1.show()
# Out:
# <div>                            <div id="2873d8d7-1a95-468a-8e7e-f61ee1a9dc08" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2873d8d7-1a95-468a-8e7e-f61ee1a9dc08")) {                    Plotly.newPlot(                        "2873d8d7-1a95-468a-8e7e-f61ee1a9dc08",                        [{"branchvalues": "total", "customdata": [["AARON MILSTONE", "Internal Medicine", "Pulmonary Disease", "4323 CAROTHERS PKWY", "SUITE 605", "FRANKLIN", "TN", "37067", 665.0], ["AARON PORTER", "Ophthalmology", "None", "3252 ASPEN GROVE DRIVE", "SUITE 1", "FRANKLIN", "TN", "37067", 379.0], ["ABU FAKHRUDDIN", "Internal Medicine", "Gastroenterology", "330 23RD AVE N", "SUITE 300", "NASHVILLE", "TN", "37203", 573.0], ["ADAM PRUDOFF", "Internal Medicine", "Cardiovascular Disease", "3601 TVC", null, "NASHVILLE", "TN", "37232", 1208.0], ["AHMAD ABU-HALIMAH", "Internal Medicine", "Cardiovascular Disease", "VANDERBILT UNIVERSITY MEDICAL CTR. CARDIOLOGY DIVISION.", "383 PRB, 2220 PIERCE AVE.", "NASHVILLE", "TN", "37232", 487.0], ["ALBERTO GONZALEZ-BERNAL", "Internal Medicine", "Critical Care Medicine", "3443 DICKERSON PK", "SUITE 680", "NASHVILLE", "TN", "37207", 759.0], ["AMANDA DANIEL", "Internal Medicine", "Endocrinology, Diabetes & Metabolism", "330 23RD AVE N", "SUITE 500", "NASHVILLE", "TN", "37203", 283.0], ["AMIT CHOKSI", "Internal Medicine", "Gastroenterology", "1222 TROTWOOD AVENUE", "STE 501", "COLUMBIA", "TN", "38401", 1271.0], ["AMIT KESWANI", "Internal Medicine", "Cardiovascular Disease", "3601 THE VANDERBILT CLINIC", null, "NASHVILLE", "TN", "37232", 722.0], ["AMIT SINGH", "Internal Medicine", "None", "300 STONECREST BLVD STE 110", null, "SMYRNA", "TN", "37167", 651.0], ["ANDREA BECK", "Internal Medicine", "None", "2400 PATTERSON ST", "SUITE 400", "NASHVILLE", "TN", "37203", 252.0], ["ANDREW GOODMAN", "Internal Medicine", "Interventional Cardiology", "2400 PATTERSON ST STE 502", null, "NASHVILLE", "TN", "37203", 396.0], ["ANDREW MCRAE", "Internal Medicine", "Advanced Heart Failure and Transplant Cardiology", "2400 PATTERSON ST", "SUITE 502", "NASHVILLE", "TN", "37203", 813.0], ["ANDREW MCVIE", "Specialist", "None", "4220 HARDING RD", null, "NASHVILLE", "TN", "37205", 795.0], ["ANDREW SAGER", "Internal Medicine", "Cardiovascular Disease", "222 22ND AVE N", "STE 400", "NASHVILLE", "TN", "37203", 468.0], ["ANDREW ZURICK", "Internal Medicine", "Cardiovascular Disease", "4230 HARDING RD.", "SUITE 330", "NASHVILLE", "TN", "37205", 1265.0], ["ANGELO CANONICO", "Internal Medicine", "Pulmonary Disease", "4230 HARDING RD", "SUITE 400", "NASHVILLE", "TN", "37205", 861.0], ["ANNIS MARNEY", "Internal Medicine", "Endocrinology, Diabetes & Metabolism", "330 23RD AVE N", "SUITE 500", "NASHVILLE", "TN", "37203", 373.0], ["ANSEL ANDERSON", "Specialist", "None", "4220 HARDING RD", null, "NASHVILLE", "TN", "37205", 834.0], ["ANTHONY KHIM", "Specialist", "None", "101 BERRYWOOD DR", null, "COLUMBIA", "TN", "38401", 649.0], ["ARNEL PANELO", "Hospitalist", "None", "2400 PATTERSON ST", "SUITE 311", "NASHVILLE", "TN", "37203", 410.0], ["ARTHUR CONSTANTINE", "Internal Medicine", "Cardiovascular Disease", "4230 HARDING PIKE", "SUITE 330", "NASHVILLE", "TN", "37205", 628.0], ["ASHLEY ROSE", "Internal Medicine", "None", "2300 PATTERSON ST", null, "NASHVILLE", "TN", "37203", 369.0], ["BARRETT CONNER", "Internal Medicine", "Pulmonary Disease", "3443 DICKERSON PIKE", "SUITE 680", "NASHVILLE", "TN", "37207", 650.0], ["BELINDA BART", "Family Medicine", "None", "1605 NASHVILLE HWY", "SUITE 200", "COLUMBIA", "TN", "38401", 596.0], ["BEN GARDNER", "Internal Medicine", "None", "854 W JAMES CAMPBELL BLVD", "SUITE 403", "COLUMBIA", "TN", "38401", 681.0], ["BENJAMIN DEHNER", "Urology", "None", "4230 HARDING RD", "SUITE 521", "NASHVILLE", "TN", " ...

# %% [markdown]
# # Alvin Request #2

# %%
# From below, summarize by Facility Group
# Find hospital groups with the largest number of single group, non-Vanderbilt NPIs
# Remove Radiology
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi
                , COUNT(DISTINCT to_facility_group) AS to_groups
                , SUM(transaction_count) AS npi_transactions
                , SUM(patient_count) AS npi_patients
                , to_facility_group
            FROM referrals
            WHERE from_npi_specialty NOT IN ('Radiology', 'Emergency Medicine', 'Orthopaedic Surgery',
                                            'Pathology', 'Anesthesiology')
            GROUP BY from_npi
            HAVING to_groups = 1 AND npi_transactions >= 500
        ), CTE_2 AS(
            SELECT CTE.to_facility_group, CTE.npi_transactions, CTE.npi_patients, n.*
            FROM CTE
            INNER JOIN npidata_nashville AS n 
                ON CTE.from_npi = n.npi
            ORDER BY CTE.npi_transactions DESC
        )
        SELECT to_facility_group AS Facility_Group
            , npi
            , provider_first_name || ' ' || provider_last_name AS Name
            , classification AS Classification
            , COALESCE(specialization, 'None') AS Specialization
            , npi_transactions AS NPI_Transactions
            , npi_patients AS NPI_Patients
            , provider_business_address_1
            , provider_business_address_2
            , provider_business_city
            , provider_business_state
            , provider_business_zip5
            , SUM(NPI_Patients) AS Total_Patients
        FROM CTE_2
        GROUP BY to_facility_group, classification, specialization
        """ 

    poach2 = pd.read_sql(query, db)

display(poach2)
# Out:
#                            Facility_Group         npi              Name  \
# 0                  Ascension Saint Thomas  1700823713         JEFF TODD
# 1                  Ascension Saint Thomas  1013273044    MATTHEW JOSEPH
# 2                  Ascension Saint Thomas  1275828089    ZAKARIA BOTROS
# 3                  Ascension Saint Thomas  1720241185  WARREN STRIBLING
# 4                  Ascension Saint Thomas  1770519704      DAVID GIBSON
# ..                                    ...         ...               ...
# 99   Vanderbilt University Medical Center  1922107358         SAM CHANG
# 100             Williamson Medical Center  1053638148       LEVI BENSON
# 101             Williamson Medical Center  1952771941   JAYANTHI SAMUEL
# 102             Williamson Medical Center  1750327052      CARY PULLIAM
# 103             Williamson Medical Center  1750382727        JOEL LOCKE
#
#          Classification                                    Specialization  \
# 0       Family Medicine                                              None
# 1           Hospitalist                                              None
# 2     Internal Medicine                                              None
# 3     Internal Medicine  Advanced Heart Failure and Transplant Cardiology
# 4     Internal Medicine                            Cardiovascular Disease
# ..                  ...                                               ...
# 99              Urology                                              None
# 100         Hospitalist                                              None
# 101  Nurse Practitioner                                            Family
# 102             Surgery                                  Vascular Surgery
# 103             Urology                                              None
#
#      NPI_Transactions  NPI_Patients provider_business_address_1  \
# 0                 679           435            205 S MCCRARY ST
# 1                 509           487           4220 HARDING PIKE
# 2                 693           623    1700 MEDICAL CENTER PKWY
# 3                1648           711            4230 HARDING RD.
# 4                1648          1454             4230 HARDING RD
# ..                ...           ...                         ...
# 99               1441           733                    3601 TVC
# 100               716           558         4321 CAROTHERS PKWY
# 101               519           467         4323 CAROTHERS PKWY
# 102               691           385         4601 CAROTHERS PKWY
# 103               747           488         4601 CAROTHERS PKWY
#
#     provider_business_address_2 provider_business_city  \
# 0                          None               WOODBURY
# 1                     SUITE 500              NASHVILLE
# 2                          None           MURFREESBORO
# 3                      STE. 330              NASHVILLE
# 4                     SUITE 330              NASHVILLE
# ..                          ...                    ...
# 99                         None              NASHVILLE
# 100                        None               FRANKLIN
# 101                   SUITE 205               FRANKLIN
# 102                     STE 375               FRANKLIN
# 103                   SUITE 475               FRANKLIN
#
#     provider_business_state provider_business_zip5  Total_Patients
# 0                        TN                  37190             832
# 1                        TN                  37205             487
# 2                        TN                  37129            3065
# 3                        TN                  37205            1879
# 4                        TN                  37205           14706
# ..                      ...                    ...             ...
# 99                       TN                  37232            3442
# 100                      TN                  37067             558
# 101                      TN                  37067             467
# 102                      TN                  37067             715
# 103                      TN                  37067            1272
#
# [104 rows x 13 columns]

# %%
fig_2 = px.treemap(poach2, path=['Facility_Group', 'Classification', 'Specialization'], values='Total_Patients',
                color='Total_Patients', 
                hover_data=['Name', 'Classification', 'Specialization', 'provider_business_address_1',
                           'provider_business_address_2', 'provider_business_city',
                           'provider_business_state', 'provider_business_zip5'],
                color_continuous_scale='Emrld')
fig_2.show()
# Out:
# <div>                            <div id="3c3292fb-55ec-40f2-a59a-61ee1759011d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c3292fb-55ec-40f2-a59a-61ee1759011d")) {                    Plotly.newPlot(                        "3c3292fb-55ec-40f2-a59a-61ee1759011d",                        [{"branchvalues": "total", "customdata": [["FRANKLIN GRAUZER", "Nurse Practitioner", "Acute Care", "4230 HARDING RD", "SUITE 435", "NASHVILLE", "TN", "37205", 547.0], ["LUCAS NEUFELD", "Nurse Practitioner", "Acute Care", "2300 PATTERSON ST", null, "NASHVILLE", "TN", "37203", 554.0], ["EMILY SKOTTE", "Nurse Practitioner", "Acute Care", "3601 THE VANDERBILT CLINIC", null, "NASHVILLE", "TN", "37232", 1061.0], ["MARNI GROVES", "Nurse Practitioner", "Adult Health", "1301 MEDICAL CENTER DR", "TVC SUITE 2501", "NASHVILLE", "TN", "37232", 2069.0], ["WARREN STRIBLING", "Internal Medicine", "Advanced Heart Failure and Transplant Cardiology", "4230 HARDING RD.", "STE. 330", "NASHVILLE", "TN", "37205", 1879.0], ["THOMAS JOHNSTON", "Internal Medicine", "Advanced Heart Failure and Transplant Cardiology", "2400 PATTERSON ST", "SUITE 502", "NASHVILLE", "TN", "37203", 2032.0], ["DOUGLAS BRINKLEY", "Internal Medicine", "Advanced Heart Failure and Transplant Cardiology", "3601 THE VANDERBILT CLINIC", "VANDERBILT HEART & VASCULAR INSTITUTE", "NASHVILLE", "TN", "37232", 2092.0], ["DAVID GIBSON", "Internal Medicine", "Cardiovascular Disease", "4230 HARDING RD", "SUITE 330", "NASHVILLE", "TN", "37205", 14706.0], ["SUNIL KAZA", "Internal Medicine", "Cardiovascular Disease", "3443 DICKERSON PIKE", "SUITE 430", "NASHVILLE", "TN", "37207", 11127.0], ["RAPHAEL SEE", "Internal Medicine", "Cardiovascular Disease", "3601 THE VANDERBILT CLINIC", null, "NASHVILLE", "TN", "37232", 23965.0], ["PETER ROBERTSON", "Internal Medicine", "Clinical Cardiac Electrophysiology", "1840 MEDICAL CENTER PKWY", "SUITE 201", "MURFREESBORO", "TN", "37129", 801.0], ["GREGORY BASHIAN", "Internal Medicine", "Clinical Cardiac Electrophysiology", "2400 PATTERSON STREET", "SUITE 502", "NASHVILLE", "TN", "37203", 1137.0], ["JAY MONTGOMERY", "Internal Medicine", "Clinical Cardiac Electrophysiology", "1215 21ST AVE S", "5TH FLOOR MEDICAL CENTER EAST", "NASHVILLE", "TN", "37232", 772.0], ["ALBERTO GONZALEZ-BERNAL", "Internal Medicine", "Critical Care Medicine", "3443 DICKERSON PK", "SUITE 680", "NASHVILLE", "TN", "37207", 759.0], ["ANNIS MARNEY", "Internal Medicine", "Endocrinology, Diabetes & Metabolism", "330 23RD AVE N", "SUITE 500", "NASHVILLE", "TN", "37203", 1102.0], ["KATHRYN DAHIR", "Internal Medicine", "Endocrinology, Diabetes & Metabolism", "3601 TVC", null, "NASHVILLE", "TN", "37232", 3481.0], ["RHONDA GRAGG", "Nurse Practitioner", "Family", "4230 HARDING PIKE", "SUITE 435", "NASHVILLE", "TN", "37205", 506.0], ["LINDA FINE", "Nurse Practitioner", "Family", "3005 AMBROSE AVE", null, "NASHVILLE", "TN", "37207", 366.0], ["TIMOTHY DICKEY", "Nurse Practitioner", "Family", "927 N JAMES CAMPBELL BLVD", "SUITE 105", "COLUMBIA", "TN", "38401", 1636.0], ["MATTHEW BUMBALOUGH", "Nurse Practitioner", "Family", "3601 THE VANDERBILT CLINIC", null, "NASHVILLE", "TN", "37232", 1766.0], ["JAYANTHI SAMUEL", "Nurse Practitioner", "Family", "4323 CAROTHERS PKWY", "SUITE 205", "FRANKLIN", "TN", "37067", 467.0], ["KIRBY DEETER", "Podiatrist", "Foot & Ankle Surgery", "3601 TVC", null, "NASHVILLE", "TN", "37232", 467.0], ["ROLAND GARRETSON", "Internal Medicine", "Gastroenterology", "1700 MEDICAL CENTER PKWY", null, "MURFREESBORO", "TN", "37129", 1085.0], ["THOMAS LEWIS", "Internal Medicine", "Gastroenterology", "2400 PATTERSON ST", "SUITE 400", "NASHVILLE", "TN", "37203", 3687.0], ["AMIT CHOKSI", "Internal Medicine", "Gastroenterology", "1222 TROTWOOD AVENUE", "STE 501", "COLUMBIA" ...

# %% [markdown]
# # Alvin Request #3

# %%
# From below, summarize by Facility Group
# Find hospital groups with the largest number of single group, non-Vanderbilt NPIs
# Remove Radiology
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi
                , COUNT(DISTINCT to_facility_group) AS to_groups
                , SUM(transaction_count) AS npi_transactions
                , SUM(patient_count) AS npi_patients
                , to_facility_group
            FROM referrals
            WHERE from_npi_specialty NOT IN ('Radiology', 'Emergency Medicine', 'Orthopaedic Surgery',
                                            'Pathology', 'Anesthesiology')
            GROUP BY from_npi
            HAVING to_groups = 1 AND npi_transactions >= 500
        ), CTE_2 AS(
            SELECT CTE.to_facility_group, CTE.npi_transactions, CTE.npi_patients, n.*
            FROM CTE
            INNER JOIN npidata_nashville AS n 
                ON CTE.from_npi = n.npi
            ORDER BY CTE.npi_transactions DESC
        )
        SELECT to_facility_group AS Facility_Group
            , npi
            , provider_first_name || ' ' || provider_last_name AS Name
            , classification AS Classification
            , COALESCE(specialization, 'None') AS Specialization
            , npi_transactions AS NPI_Transactions
            , npi_patients AS NPI_Patients
            , provider_business_address_1
            , provider_business_address_2
            , provider_business_city
            , provider_business_state
            , provider_business_zip5
            , SUM(NPI_Patients) AS Total_Patients
        FROM CTE_2
        GROUP BY classification, specialization, to_facility_group
        """ 

    poach3 = pd.read_sql(query, db)

display(poach3)
# Out:
#                            Facility_Group         npi                 Name  \
# 0    Vanderbilt University Medical Center  1265530117          JAMI MILLER
# 1                  Ascension Saint Thomas  1700823713            JEFF TODD
# 2                                     HCA  1467447664        MATTHEW BRUST
# 3           Maury Regional Medical Center  1932188554         DAVID TURNER
# 4       Riverview Regional Medical Center  1346345154        BOWDOIN SMITH
# ..                                    ...         ...                  ...
# 99                 Ascension Saint Thomas  1649481938      BENJAMIN DEHNER
# 100                                   HCA  1720245301  CHRISTOPHER HAWKINS
# 101         Maury Regional Medical Center  1710955034       JAMES MARSHALL
# 102  Vanderbilt University Medical Center  1922107358            SAM CHANG
# 103             Williamson Medical Center  1750382727           JOEL LOCKE
#
#       Classification Specialization  NPI_Transactions  NPI_Patients  \
# 0        Dermatology           None               836           523
# 1    Family Medicine           None               679           435
# 2    Family Medicine           None              1098           278
# 3    Family Medicine           None               767           500
# 4    Family Medicine           None               785           201
# ..               ...            ...               ...           ...
# 99           Urology           None               702           403
# 100          Urology           None               529           321
# 101          Urology           None              1051           600
# 102          Urology           None              1441           733
# 103          Urology           None               747           488
#
#     provider_business_address_1 provider_business_address_2  \
# 0               719 THOMPSON LN                 SUITE 26300
# 1              205 S MCCRARY ST                        None
# 2                397 WALLACE RD                   SUITE 100
# 3                 1114 W 7TH ST                        None
# 4                 9 MAGGART CIR                        None
# ..                          ...                         ...
# 99              4230 HARDING RD                   SUITE 521
# 100            5651 FRIST BLVD.                     STE 616
# 101           1222 TROTWOOD AVE                   SUITE 601
# 102                    3601 TVC                        None
# 103         4601 CAROTHERS PKWY                   SUITE 475
#
#     provider_business_city provider_business_state provider_business_zip5  \
# 0                NASHVILLE                      TN                  37204
# 1                 WOODBURY                      TN                  37190
# 2                NASHVILLE                      TN                  37211
# 3                 COLUMBIA                      TN                  38401
# 4                 CARTHAGE                      TN                  37030
# ..                     ...                     ...                    ...
# 99               NASHVILLE                      TN                  37205
# 100              HERMITAGE                      TN                  37076
# 101               COLUMBIA                      TN                  38401
# 102              NASHVILLE                      TN                  37232
# 103               FRANKLIN                      TN                  37067
#
#      Total_Patients
# 0              1873
# 1               832
# 2              2756
# 3               500
# 4               201
# ..              ...
# 99              403
# 100             321
# 101            1165
# 102            3442
# 103            1272
#
# [104 rows x 13 columns]

# %%
fig_2 = px.treemap(poach3, path=['Classification', 'Specialization', 'Facility_Group'], values='Total_Patients',
                color='Total_Patients', 
                hover_data=['Name', 'Classification', 'Specialization', 'provider_business_address_1',
                           'provider_business_address_2', 'provider_business_city',
                           'provider_business_state', 'provider_business_zip5'],
                color_continuous_scale='Emrld')
fig_2.show()
# Out:
# <div>                            <div id="24fdf83c-4967-4198-a7c8-b3b708030a1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24fdf83c-4967-4198-a7c8-b3b708030a1a")) {                    Plotly.newPlot(                        "24fdf83c-4967-4198-a7c8-b3b708030a1a",                        [{"branchvalues": "total", "customdata": [["FRANKLIN GRAUZER", "Nurse Practitioner", "Acute Care", "4230 HARDING RD", "SUITE 435", "NASHVILLE", "TN", "37205", 547.0], ["WARREN STRIBLING", "Internal Medicine", "Advanced Heart Failure and Transplant Cardiology", "4230 HARDING RD.", "STE. 330", "NASHVILLE", "TN", "37205", 1879.0], ["DAVID GIBSON", "Internal Medicine", "Cardiovascular Disease", "4230 HARDING RD", "SUITE 330", "NASHVILLE", "TN", "37205", 14706.0], ["PETER ROBERTSON", "Internal Medicine", "Clinical Cardiac Electrophysiology", "1840 MEDICAL CENTER PKWY", "SUITE 201", "MURFREESBORO", "TN", "37129", 801.0], ["RHONDA GRAGG", "Nurse Practitioner", "Family", "4230 HARDING PIKE", "SUITE 435", "NASHVILLE", "TN", "37205", 506.0], ["ROLAND GARRETSON", "Internal Medicine", "Gastroenterology", "1700 MEDICAL CENTER PKWY", null, "MURFREESBORO", "TN", "37129", 1085.0], ["MICHAEL MORSE", "Internal Medicine", "Interventional Cardiology", "4230 HARDING PIKE", "SUITE 330", "NASHVILLE", "TN", "37205", 755.0], ["EUGENE LAFRANCHISE", "Psychiatry & Neurology", "Neurology", "4230 HARDING PIKE", "SUITE 535", "NASHVILLE", "TN", "37205", 1049.0], ["JEFF TODD", "Family Medicine", "None", "205 S MCCRARY ST", null, "WOODBURY", "TN", "37190", 832.0], ["MATTHEW JOSEPH", "Hospitalist", "None", "4220 HARDING PIKE", "SUITE 500", "NASHVILLE", "TN", "37205", 487.0], ["ZAKARIA BOTROS", "Internal Medicine", "None", "1700 MEDICAL CENTER PKWY", null, "MURFREESBORO", "TN", "37129", 3065.0], ["KERI MEEKS", "Nurse Practitioner", "None", "4230 HARDING PIKE", "SUITE 435", "NASHVILLE", "TN", "37205", 470.0], ["ANSEL ANDERSON", "Specialist", "None", "4220 HARDING RD", null, "NASHVILLE", "TN", "37205", 2967.0], ["BENJAMIN DEHNER", "Urology", "None", "4230 HARDING RD", "SUITE 521", "NASHVILLE", "TN", "37205", 403.0], ["ANGELO CANONICO", "Internal Medicine", "Pulmonary Disease", "4230 HARDING RD", "SUITE 400", "NASHVILLE", "TN", "37205", 5079.0], ["JIMBOB FAULK", "Surgery", "Vascular Surgery", "4230 HARDING RD", "SUITE 525", "NASHVILLE", "TN", "37205", 439.0], ["LUCAS NEUFELD", "Nurse Practitioner", "Acute Care", "2300 PATTERSON ST", null, "NASHVILLE", "TN", "37203", 554.0], ["THOMAS JOHNSTON", "Internal Medicine", "Advanced Heart Failure and Transplant Cardiology", "2400 PATTERSON ST", "SUITE 502", "NASHVILLE", "TN", "37203", 2032.0], ["SUNIL KAZA", "Internal Medicine", "Cardiovascular Disease", "3443 DICKERSON PIKE", "SUITE 430", "NASHVILLE", "TN", "37207", 11127.0], ["GREGORY BASHIAN", "Internal Medicine", "Clinical Cardiac Electrophysiology", "2400 PATTERSON STREET", "SUITE 502", "NASHVILLE", "TN", "37203", 1137.0], ["ALBERTO GONZALEZ-BERNAL", "Internal Medicine", "Critical Care Medicine", "3443 DICKERSON PK", "SUITE 680", "NASHVILLE", "TN", "37207", 759.0], ["ANNIS MARNEY", "Internal Medicine", "Endocrinology, Diabetes & Metabolism", "330 23RD AVE N", "SUITE 500", "NASHVILLE", "TN", "37203", 1102.0], ["LINDA FINE", "Nurse Practitioner", "Family", "3005 AMBROSE AVE", null, "NASHVILLE", "TN", "37207", 366.0], ["THOMAS LEWIS", "Internal Medicine", "Gastroenterology", "2400 PATTERSON ST", "SUITE 400", "NASHVILLE", "TN", "37203", 3687.0], ["MICHAEL HEMPHILL", "Internal Medicine", "Hematology & Oncology", "5653 FRIST BLVD", "STE 434", "HERMITAGE", "TN", "37076", 1061.0], ["JULI HORTON", "Internal Medicine", "Infectious Disease", "2400 PATTERSON ST", "SUITE 400", "NASHVILLE", "TN", "37203", 382.0], ["TARAL PATEL", "Internal Medicine", "Intervention ...

# %% [markdown]
# # CURRENT PROJECT

# %%
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH vandy_selector AS (
            SELECT from_npi, patient_count, CASE
                WHEN to_facility_group = 'Vanderbilt University Medical Center' THEN 'vandy'
                ELSE 'not_vandy' END AS to_vandy,
                SUM(patient_count) OVER(PARTITION BY from_npi) AS total_patients
            FROM referrals
        ), percents AS (
            SELECT from_npi AS npi
                , patient_count AS non_vandy_patients
                , total_patients
                , ROUND(100.0 * patient_count/total_patients, 2) AS pct_competition
            FROM vandy_selector
            WHERE to_vandy = 'not_vandy'
            GROUP BY from_npi, to_vandy
        ), npi_details AS (
            SELECT npi
                , provider_first_name || ' ' || provider_last_name AS Name
                , classification AS Classification
                , COALESCE(specialization, 'None') AS Specialization
                , provider_business_address_1
                , provider_business_address_2
                , provider_business_city
                , provider_business_state
                , provider_business_zip5
            FROM npidata_nashville
            GROUP BY npi
        )
        SELECT *
        FROM percents
        JOIN npi_details USING(npi)
        WHERE classification NOT IN ('Radiology', 'Emergency Medicine', 
                                    'Orthopaedic Surgery','Pathology', 'Anesthesiology')
        AND total_patients >= 500
        """ 

    percents_treemap = pd.read_sql(query, db)

display(percents_treemap)
# Out:
#             npi  non_vandy_patients  total_patients  pct_competition  \
# 0    1003819277                  91             675            13.48
# 1    1013179860                  71            1241             5.72
# 2    1013908730                 462             548            84.31
# 3    1013958776                 487            1044            46.65
# 4    1023000999                 227             626            36.26
# ..          ...                 ...             ...              ...
# 310  1962656322                 511             511           100.00
# 311  1972658060                1770            1878            94.25
# 312  1982661617                  96             680            14.12
# 313  1982796306                 247             752            32.85
# 314  1992064935                  82             686            11.95
#
#                    Name     Classification             Specialization  \
# 0             JOHN CAGE  Internal Medicine     Cardiovascular Disease
# 1             GARY YAWN  Internal Medicine  Interventional Cardiology
# 2         JOSEPH PARKER  Internal Medicine           Gastroenterology
# 3     AHMAD ABU-HALIMAH  Internal Medicine     Cardiovascular Disease
# 4          CLARA WOMACK  Internal Medicine                 Nephrology
# ..                  ...                ...                        ...
# 310  CANDICE OLECHOWSKI  Internal Medicine                       None
# 311         TERRY KETCH  Internal Medicine     Cardiovascular Disease
# 312      CHRISTIE GREEN  Internal Medicine                 Nephrology
# 313      MATTHEW ABBATE  Internal Medicine                       None
# 314      MENGISTU BERIE  Internal Medicine                       None
#
#                            provider_business_address_1  \
# 0                                       222 22ND AVE N
# 1                   353 NEW SHACKLE ISLAND RD STE 300C
# 2                                       222 22ND AVE N
# 3    VANDERBILT UNIVERSITY MEDICAL CTR. CARDIOLOGY ...
# 4                                       393 WALLACE RD
# ..                                                 ...
# 310                                  1224 TROTWOOD AVE
# 311                        3443 DICKERSON PIKE STE 430
# 312                                   1617 WILLIAMS DR
# 313                                           3601 TVC
# 314                        1005 DR. D.B.TODD JR. BLVD.
#
#     provider_business_address_2 provider_business_city  \
# 0                       STE 400              NASHVILLE
# 1                          None         HENDERSONVILLE
# 2                          None              NASHVILLE
# 3     383 PRB, 2220 PIERCE AVE.              NASHVILLE
# 4                      STE. 203              NASHVILLE
# ..                          ...                    ...
# 310                        None               COLUMBIA
# 311                        None              NASHVILLE
# 312                    STE. 200           MURFREESBORO
# 313                        None              NASHVILLE
# 314                        None               NASHVILE
#
#     provider_business_state provider_business_zip5
# 0                        TN                  37203
# 1                        TN                  37075
# 2                        TN                  37203
# 3                        TN                  37232
# 4                        TN                  37211
# ..                      ...                    ...
# 310                      TN                  38401
# 311                      TN                  37207
# 312                      TN                  37129
# 313                      TN                  37232
# 314                      TN                  37208
#
# [315 rows x 12 columns]

# %%
fig = px.treemap(percents_treemap, path=['Classification', 'Specialization', 'Name'], values='non_vandy_patients',
                color='pct_competition', 
                hover_data=['Name', 'Classification', 'Specialization', 'provider_business_address_1',
                           'provider_business_address_2', 'provider_business_city',
                           'provider_business_state', 'provider_business_zip5', 'total_patients'],
                color_continuous_scale='Emrld')
fig.show()
# Out:
# <div>                            <div id="a4afdfaa-5629-443e-b3bd-9e8122ca2393" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4afdfaa-5629-443e-b3bd-9e8122ca2393")) {                    Plotly.newPlot(                        "a4afdfaa-5629-443e-b3bd-9e8122ca2393",                        [{"branchvalues": "total", "customdata": [["AARON MILSTONE", "Internal Medicine", "Pulmonary Disease", "4323 CAROTHERS PKWY", "SUITE 605", "FRANKLIN", "TN", "37067", 1023, 65.0], ["ABU FAKHRUDDIN", "Internal Medicine", "Gastroenterology", "330 23RD AVE N", "SUITE 300", "NASHVILLE", "TN", "37203", 573, 100.0], ["ADAM PRUDOFF", "Internal Medicine", "Cardiovascular Disease", "3601 TVC", null, "NASHVILLE", "TN", "37232", 2721, 44.4], ["AHMAD ABU-HALIMAH", "Internal Medicine", "Cardiovascular Disease", "VANDERBILT UNIVERSITY MEDICAL CTR. CARDIOLOGY DIVISION.", "383 PRB, 2220 PIERCE AVE.", "NASHVILLE", "TN", "37232", 1044, 46.65], ["ALBERTO GONZALEZ-BERNAL", "Internal Medicine", "Critical Care Medicine", "3443 DICKERSON PK", "SUITE 680", "NASHVILLE", "TN", "37207", 759, 100.0], ["ALEXANDER BADRU", "Internal Medicine", "None", "521 WEST MAIN STREET", null, "LEBANON", "TN", "37087", 588, 15.14], ["ALLEN NAFTILAN", "Internal Medicine", "Cardiovascular Disease", "3601 TVC", null, "NASHVILLE", "TN", "37232", 1201, 2.08], ["AMIT CHOKSI", "Internal Medicine", "Gastroenterology", "1222 TROTWOOD AVENUE", "STE 501", "COLUMBIA", "TN", "38401", 1271, 100.0], ["AMIT KESWANI", "Internal Medicine", "Cardiovascular Disease", "3601 THE VANDERBILT CLINIC", null, "NASHVILLE", "TN", "37232", 890, 81.12], ["AMIT SINGH", "Internal Medicine", "None", "300 STONECREST BLVD STE 110", null, "SMYRNA", "TN", "37167", 695, 38.99], ["ANDRE OLIVIER", "Internal Medicine", "Cardiovascular Disease", "100 PHYSICIANS WAY", "SUITE 300", "LEBANON", "TN", "37090", 971, 41.19], ["ANDREW MCRAE", "Internal Medicine", "Advanced Heart Failure and Transplant Cardiology", "2400 PATTERSON ST", "SUITE 502", "NASHVILLE", "TN", "37203", 813, 4.67], ["ANDREW MCVIE", "Specialist", "None", "4220 HARDING RD", null, "NASHVILLE", "TN", "37205", 795, 100.0], ["ANDREW ZURICK", "Internal Medicine", "Cardiovascular Disease", "4230 HARDING RD.", "SUITE 330", "NASHVILLE", "TN", "37205", 1265, 87.91], ["ANGELO CANONICO", "Internal Medicine", "Pulmonary Disease", "4230 HARDING RD", "SUITE 400", "NASHVILLE", "TN", "37205", 861, 100.0], ["ANIL NACHNANI", "Internal Medicine", "None", "300 STEAM PLANT RD.", "STE 300", "GALLATIN", "TN", "37066", 546, 15.2], ["ANSEL ANDERSON", "Specialist", "None", "4220 HARDING RD", null, "NASHVILLE", "TN", "37205", 834, 100.0], ["ANTHONY KHIM", "Specialist", "None", "101 BERRYWOOD DR", null, "COLUMBIA", "TN", "38401", 649, 100.0], ["ANUMEET PRIYADARSHI", "Internal Medicine", "Nephrology", "270 EAST MAIN STREET", "SUITE 200", "GALLATIN", "TN", "37066", 665, 15.04], ["ARTHUR CONSTANTINE", "Internal Medicine", "Cardiovascular Disease", "4230 HARDING PIKE", "SUITE 330", "NASHVILLE", "TN", "37205", 628, 85.03], ["ARVINDH KANAGASUNDRAM", "Internal Medicine", "Cardiovascular Disease", "1215 21ST AVE S", "VHVI, MCE SOUTH TOWER, SUITE 5209", "NASHVILLE", "TN", "37232", 1658, 13.93], ["ASHISH SONI", "Internal Medicine", "Nephrology", "111 HIGHWAY 70 E", "STE. E", "DICKSON", "TN", "37055", 852, 13.15], ["B. DUNN", "Internal Medicine", "Nephrology", "2010 CHURCH ST", "STE. 508", "NASHVILLE", "TN", "37203", 545, 13.39], ["BARRETT CONNER", "Internal Medicine", "Pulmonary Disease", "3443 DICKERSON PIKE", "SUITE 680", "NASHVILLE", "TN", "37207", 650, 100.0], ["BELINDA BART", "Family Medicine", "None", "1605 NASHVILLE HWY", "SUITE 200", "COLUMBIA", "TN", "38401", 729, 81.76], ["BEN GARDNER", "Internal Medicine", "None", "854 W JAMES CAMPBELL BLVD", "SUITE 403", "C ...

# %%
# From below, summarize by Classification
# Find classifications with largest number of transactions to non_vandy
# Find percentage of non_Vandhy
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi
                , COUNT(DISTINCT to_facility_group) AS to_groups
                , SUM(transaction_count) AS npi_transactions
                , SUM(patient_count) AS npi_patients
                , to_facility_group
            FROM referrals
            AND from_npi_specialty NOT IN ('Radiology', 'Emergency Medicine', 'Orthopaedic Surgery',
                                            'Pathology', 'Anesthesiology')
            GROUP BY from_npi
            HAVING to_groups = 1 AND npi_transactions >= 500
        ), CTE_2 AS(
            SELECT CTE.to_facility_group, CTE.npi_transactions, CTE.npi_patients, n.*
            FROM CTE
            INNER JOIN npidata_nashville AS n 
                ON CTE.from_npi = n.npi
            ORDER BY CTE.npi_transactions DESC
        )
        SELECT to_facility_group AS Facility_Group
            , npi
            , provider_first_name || ' ' || provider_last_name AS Name
            , classification AS Classification
            , specialization AS Specialization
            , npi_transactions AS NPI_Transactions
            , npi_patients AS NPI_Patients
            , provider_business_address_1
            , provider_business_address_2
            , provider_business_city
            , provider_business_state
            , provider_business_zip5
        FROM CTE_2
        ORDER BY to_facility_group
        """ 

    poach_two = pd.read_sql(query, db)

display(poach_two)

# %%
# From below, summarize by Classification
# Find classifications with largest number of transactions to non_vandy
# Find percentage of non_Vandhy
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi
                , COUNT(DISTINCT to_facility_group) AS to_groups
                , SUM(transaction_count) AS npi_transactions
                , SUM(patient_count) AS npi_patients
                , to_facility_group
            FROM referrals
            WHERE from_npi_specialty NOT IN ('Radiology', 'Emergency Medicine', 'Orthopaedic Surgery',
                                            'Pathology', 'Anesthesiology')
            GROUP BY from_npi, 
        )
        SELECT CTE.to_facility_group, CTE.npi_transactions, CTE.npi_patients, n.*
        FROM CTE
        INNER JOIN npidata_nashville AS n 
            ON CTE.from_npi = n.npi
        ORDER BY CTE.npi_transactions DESC
        """ 

    poach_two = pd.read_sql(query, db)

display(poach_two)
# Out:
#                          to_facility_group  npi_transactions  npi_patients  \
# 0                                      HCA              6823          5195
# 1            Maury Regional Medical Center              6027          1822
# 2            Macon County General Hospital              4570          3091
# 3            Macon County General Hospital              3845          2521
# 4            Macon County General Hospital              3688          2542
# ...                                    ...               ...           ...
# 3351                                   HCA                50            50
# 3352                                   HCA                50            49
# 3353                Ascension Saint Thomas                50            29
# 3354  Vanderbilt University Medical Center                50            46
# 3355                Ascension Saint Thomas                50            37
#
#              npi entity_type_code provider_org_name provider_last_name  \
# 0     1417131715                1              None            RIDDICK
# 1     1174517593                1              None              NEUSS
# 2     1104933738                1              None                LEE
# 3     1790891315                1              None              RUSSO
# 4     1679689285                1              None          CALLISTER
# ...          ...              ...               ...                ...
# 3351  1063742229                1              None             WOOTEN
# 3352  1619291242                1              None             KELLEY
# 3353  1376809590                1              None             ZELLER
# 3354  1992057509                1              None            MARCRUM
# 3355  1487096459                1              None               GARG
#
#      provider_first_name provider_middle_name provider_name_prefix  \
# 0                   JOHN               ALSTON                  DR.
# 1                MICHAEL              NORBERT                  DR.
# 2                   JUNG                   H.                 None
# 3                 DONALD                    J                 None
# 4                  TRACY                   Q.                 None
# ...                  ...                  ...                  ...
# 3351               SARAH                  ANN                 None
# 3352              SHERRY                    L                 None
# 3353                EMEM               ASUQUO                 None
# 3354               TRACI                 None                 None
# 3355               RICHA                 None                  DR.
#
#      provider_name_suffix provider_credential  \
# 0                    None                M.D.
# 1                    None                M.D.
# 2                    None                M.D.
# 3                    None                M.D.
# 4                    None                M.D.
# ...                   ...                 ...
# 3351                 None                CRNA
# 3352                 None                CRNA
# 3353                 None            APN NP-C
# 3354                 None                N.P.
# 3355                 None                M.D.
#
#                             provider_business_address_1  \
# 0                                     2400 PATTERSON ST
# 1     2220 PIERCE AVENUE, VANDERBILT INGRAM CANCER C...
# 2                             353 NEW SHACKLE ISLAND RD
# 3                             353 NEW SHACKLE ISLAND RD
# 4                             353 NEW SHACKLE ISLAND RD
# ...                                                 ...
# 3351                                     110 29TH AVE N
# 3352                             110 29TH AVE N STE 202
# 3353                         28 WHITE BRIDGE RD STE 208
# 3354                         3601 THE VANDERBILT CLINIC
# 3355                                1020 N HIGHLAND AVE
#
#               provider_business_address_2 provider_business_city  \
# 0                               SUITE 502              NASHVILLE
# 1     VANDERBILT UNIVERSITY MEDICAL CENTR              NASHVILLE
# 2                                   #300C         HENDERSONVILLE
# 3                                   #300C         HENDERSONVILLE
# 4                                   #300C         HENDERSONVILLE
# ...                                   ...                    ...
# 3351                              STE 202              NASHVILLE
# 3352                                 None              NASHVILLE
# 3353                                 None              NASHVILLE
# 3354                                 None              NASHVILLE
# 3355                                 None           MURFREESBORO
#
#      provider_business_state provider_business_zip taxonomy_code  \
# 0                         TN             372031562    207RI0011X
# 1                         TN             372326683    207RH0003X
# 2                         TN             370752379    207RC0000X
# 3                         TN             370752379    207RC0000X
# 4                         TN             370752379    207RC0000X
# ...                      ...                   ...           ...
# 3351                      TN             372031401    367500000X
# 3352                      TN             372031448    367500000X
# 3353                      TN             372051467    363LF0000X
# 3354                      TN             372328802    363LA2100X
# 3355                      TN             371302494    207Q00000X
#
#      provider_business_zip5    zip   cbsa  \
# 0                     37203  37203  34980
# 1                     37232  37232  34980
# 2                     37075  37075  34980
# 3                     37075  37075  34980
# 4                     37075  37075  34980
# ...                     ...    ...    ...
# 3351                  37203  37203  34980
# 3352                  37203  37203  34980
# 3353                  37205  37205  34980
# 3354                  37232  37232  34980
# 3355                  37130  37130  34980
#
#                                                grouping  \
# 0                   Allopathic & Osteopathic Physicians
# 1                   Allopathic & Osteopathic Physicians
# 2                   Allopathic & Osteopathic Physicians
# 3                   Allopathic & Osteopathic Physicians
# 4                   Allopathic & Osteopathic Physicians
# ...                                                 ...
# 3351  Physician Assistants & Advanced Practice Nursi...
# 3352  Physician Assistants & Advanced Practice Nursi...
# 3353  Physician Assistants & Advanced Practice Nursi...
# 3354  Physician Assistants & Advanced Practice Nursi...
# 3355                Allopathic & Osteopathic Physicians
#
#                                classification             specialization
# 0                           Internal Medicine  Interventional Cardiology
# 1                           Internal Medicine      Hematology & Oncology
# 2                           Internal Medicine     Cardiovascular Disease
# 3                           Internal Medicine     Cardiovascular Disease
# 4                           Internal Medicine     Cardiovascular Disease
# ...                                       ...                        ...
# 3351  Nurse Anesthetist, Certified Registered                       None
# 3352  Nurse Anesthetist, Certified Registered                       None
# 3353                       Nurse Practitioner                     Family
# 3354                       Nurse Practitioner                 Acute Care
# 3355                          Family Medicine                       None
#
# [3356 rows x 24 columns]

# %%
IsNull(FieldName, 0)

# %%
# From below, summarize by specialization
# Find hospital groups with the largest number of single group, non-Vanderbilt NPIs
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi
                , COUNT(DISTINCT to_facility_group) AS to_groups
                , SUM(transaction_count) AS npi_transactions
                , to_facility_group
            FROM referrals
            WHERE to_facility_group <> 'Vanderbilt University Medical Center'
            GROUP BY from_npi
            HAVING to_groups = 1 AND npi_transactions >= 1000
        ), CTE_2 AS(
            SELECT CTE.to_facility_group, n.*, CTE.npi_transactions 
            FROM CTE
            INNER JOIN npidata_nashville AS n 
                ON CTE.from_npi = n.npi
            ORDER BY CTE.npi_transactions DESC
        )
        SELECT classification, COUNT(classification), SUM(npi_transactions)
        FROM CTE_2
        GROUP BY classification
        ORDER BY SUM(npi_transactions) DESC 
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#         classification  COUNT(classification)  SUM(npi_transactions)
# 0            Radiology                     48                 118352
# 1    Internal Medicine                     52                  75354
# 2      Family Medicine                      2                   2519
# 3            Pathology                      2                   2437
# 4       Otolaryngology                      2                   2203
# 5  Orthopaedic Surgery                      1                   1253
# 6              Surgery                      1                   1239
# 7   Nurse Practitioner                      1                   1113
# 8           Specialist                      1                   1090
# 9              Urology                      1                   1051

# %%
# Find NPIs sending to single facility group
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi, COUNT(DISTINCT to_facility_group) AS to_groups, SUM(transaction_count) AS npi_transactions
            FROM referrals
            GROUP BY from_npi
        )
        SELECT n.*, CTE.npi_transactions 
        FROM CTE
        INNER JOIN npidata_nashville AS n 
            ON CTE.from_npi = n.npi
        WHERE CTE.to_groups = 1
        ORDER BY CTE.npi_transactions DESC
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#              npi entity_type_code provider_org_name provider_last_name  \
# 0     1871548818                1              None              KLEIN
# 1     1376756742                1              None            GRIFFIN
# 2     1316983695                1              None          GUTTENTAG
# 3     1740377845                1              None              TABER
# 4     1043302466                1              None              BLOCK
# ...          ...              ...               ...                ...
# 2587  1619291242                1              None             KELLEY
# 2588  1376809590                1              None             ZELLER
# 2589  1992057509                1              None            MARCRUM
# 2590  1487096459                1              None               GARG
# 2591  1639598964                1              None             CIRBUS
#
#      provider_first_name provider_middle_name provider_name_prefix  \
# 0                WILLIAM                    J                  DR.
# 1               BENJAMIN                DAVID                 None
# 2                   ADAM                    R                 None
# 3                  DAVID                 None                 None
# 4                   JOHN                 None                 None
# ...                  ...                  ...                  ...
# 2587              SHERRY                    L                 None
# 2588                EMEM               ASUQUO                 None
# 2589               TRACI                 None                 None
# 2590               RICHA                 None                  DR.
# 2591               JAMIE                 None                 None
#
#      provider_name_suffix provider_credential provider_business_address_1  \
# 0                    None                  MD      210 25TH AVE N STE 602
# 1                    None                M.D.              210 25TH AVE N
# 2                    None                  MD  3601 THE VANDERBILT CLINIC
# 3                    None                  MD                    3601 TVC
# 4                    None                  MD                    3601 TVC
# ...                   ...                 ...                         ...
# 2587                 None                CRNA      110 29TH AVE N STE 202
# 2588                 None            APN NP-C  28 WHITE BRIDGE RD STE 208
# 2589                 None                N.P.  3601 THE VANDERBILT CLINIC
# 2590                 None                M.D.         1020 N HIGHLAND AVE
# 2591                 None                  MD  3601 THE VANDERBILT CLINIC
#
#      provider_business_address_2 provider_business_city  \
# 0                           None              NASHVILLE
# 1                           None              NASHVILLE
# 2                           None              NASHVILLE
# 3                           None              NASHVILLE
# 4                           None              NASHVILLE
# ...                          ...                    ...
# 2587                        None              NASHVILLE
# 2588                        None              NASHVILLE
# 2589                        None              NASHVILLE
# 2590                        None           MURFREESBORO
# 2591                        None              NASHVILLE
#
#      provider_business_state provider_business_zip taxonomy_code  \
# 0                         TN                 37203    2085R0202X
# 1                         TN                 37203    2085R0202X
# 2                         TN             372320001    2085R0202X
# 3                         TN             372320001    2085R0202X
# 4                         TN             372320001    2085R0202X
# ...                      ...                   ...           ...
# 2587                      TN             372031448    367500000X
# 2588                      TN             372051467    363LF0000X
# 2589                      TN             372328802    363LA2100X
# 2590                      TN             371302494    207Q00000X
# 2591                      TN             372324700    207P00000X
#
#      provider_business_zip5    zip   cbsa  \
# 0                     37203  37203  34980
# 1                     37203  37203  34980
# 2                     37232  37232  34980
# 3                     37232  37232  34980
# 4                     37232  37232  34980
# ...                     ...    ...    ...
# 2587                  37203  37203  34980
# 2588                  37205  37205  34980
# 2589                  37232  37232  34980
# 2590                  37130  37130  34980
# 2591                  37232  37232  34980
#
#                                                grouping  \
# 0                   Allopathic & Osteopathic Physicians
# 1                   Allopathic & Osteopathic Physicians
# 2                   Allopathic & Osteopathic Physicians
# 3                   Allopathic & Osteopathic Physicians
# 4                   Allopathic & Osteopathic Physicians
# ...                                                 ...
# 2587  Physician Assistants & Advanced Practice Nursi...
# 2588  Physician Assistants & Advanced Practice Nursi...
# 2589  Physician Assistants & Advanced Practice Nursi...
# 2590                Allopathic & Osteopathic Physicians
# 2591                Allopathic & Osteopathic Physicians
#
#                                classification        specialization  \
# 0                                   Radiology  Diagnostic Radiology
# 1                                   Radiology  Diagnostic Radiology
# 2                                   Radiology  Diagnostic Radiology
# 3                                   Radiology  Diagnostic Radiology
# 4                                   Radiology  Diagnostic Radiology
# ...                                       ...                   ...
# 2587  Nurse Anesthetist, Certified Registered                  None
# 2588                       Nurse Practitioner                Family
# 2589                       Nurse Practitioner            Acute Care
# 2590                          Family Medicine                  None
# 2591                       Emergency Medicine                  None
#
#       npi_transactions
# 0                 4900
# 1                 4634
# 2                 4405
# 3                 4378
# 4                 3822
# ...                ...
# 2587                50
# 2588                50
# 2589                50
# 2590                50
# 2591                50
#
# [2592 rows x 22 columns]

# %%
#Filter to Vanderbilt
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        SELECT npi, COALESCE(specialization, 'NONE')
        FROM npidata_nashville
        LIMIT 10
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#           npi COALESCE(specialization, 'NONE')
# 0  1134122187                             NONE
# 1  1003819046                       Gynecology
# 2  1750384780                             NONE
# 3  1922001957                             NONE
# 4  1073516001                             NONE
# 5  1780687830                    Cytopathology
# 6  1760485817                             NONE
# 7  1437152485                             NONE
# 8  1497758445                             NONE
# 9  1952304990           Cardiovascular Disease

# %%
# Find interesting npi_specialty
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        SELECT from_npi_specialty AS classification, COUNT(from_npi_specialty) AS classification_count
        From referrals
        GROUP BY from_npi_specialty
        ORDER BY COUNT(from_npi_specialty) DESC
        LIMIT 10
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#                             classification  classification_count
# 0                        Internal Medicine                 10774
# 1                                Radiology                  5446
# 2                       Nurse Practitioner                  3025
# 3                          Family Medicine                  2536
# 4                       Emergency Medicine                  1399
# 5  Nurse Anesthetist, Certified Registered                  1231
# 6                      Orthopaedic Surgery                  1144
# 7                           Anesthesiology                  1017
# 8                                  Surgery                   869
# 9                   Psychiatry & Neurology                   778

# %%
# Find interesting Specializations (can be filtered by specialty)
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        SELECT npidata_nashville.specialization, COUNT(npidata_nashville.specialization)
        From referrals
        JOIN npidata_nashville
        ON referrals.from_npi = npidata_nashville.npi
        WHERE referrals.from_npi_specialty = 'Nurse Practitioner'
        GROUP BY npidata_nashville.specialization
        ORDER BY COUNT(npidata_nashville.specialization) DESC
        LIMIT 10
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#               specialization  COUNT(npidata_nashville.specialization)
# 0                     Family                                     1463
# 1                 Acute Care                                      397
# 2               Adult Health                                      310
# 3  Psychiatric/Mental Health                                      131
# 4             Women's Health                                       75
# 5                Gerontology                                       52
# 6               Primary Care                                       17
# 7    Obstetrics & Gynecology                                        3
# 8     Critical Care Medicine                                        1
# 9                       None                                        0

# %%
# Find interesting Groupings (can be filtered by specialty)
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        SELECT npidata_nashville.grouping, COUNT(npidata_nashville.grouping)
        From referrals
        JOIN npidata_nashville
        ON referrals.from_npi = npidata_nashville.npi
        WHERE referrals.from_npi_specialty = 'Anesthesiology'
        GROUP BY npidata_nashville.grouping
        ORDER BY COUNT(npidata_nashville.grouping) DESC
        LIMIT 10
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#                               grouping  COUNT(npidata_nashville.grouping)
# 0  Allopathic & Osteopathic Physicians                               1017

# %%
# Find NPIs with largest number of referrals
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT SUM(transaction_count) AS total_referrals, to_npi, n.provider_org_name
    FROM filtered_hop_teaming AS f
    JOIN npidata AS n
    ON f.to_npi = n.npi
    GROUP BY to_npi
    ORDER BY total_referrals DESC
    LIMIT 20;
    """ 
    
    test = pd.read_sql(query, db)

test
# Out:
#     total_referrals      to_npi                       provider_org_name
# 0            901945  1104202761    VANDERBILT UNIVERSITY MEDICAL CENTER
# 1            635811  1437194669           SAINT THOMAS MEDICAL PARTNERS
# 2            603385  1396882205    VANDERBILT UNIVERSITY MEDICAL CENTER
# 3            598277  1093741464         ADVANCED DIAGNOSTIC IMAGING, PC
# 4            526917  1861478489                   RADIOLOGY ALLIANCE PC
# 5            445897  1003863580            ASSOCIATED PATHOLOGISTS, LLC
# 6            323305  1245393057                    CENTENNIAL HEART LLC
# 7            245119  1215932413            ANESTHESIA MEDICAL GROUP, PC
# 8            240693  1811955917                 TENNESSEE ONCOLOGY PLLC
# 9            228282  1235186800                     PATHGROUP LABS, LLC
# 10           199426  1700878360               NEPHROLOGY ASSOCIATES, PC
# 11           198922  1023055126  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 12           192221  1548284060          HERITAGE MEDICAL ASSOCIATES PC
# 13           172267  1205886264       MAURY REGIONAL MEDICAL GROUP, INC
# 14           157359  1629025648              SAINT THOMAS WEST HOSPITAL
# 15           138043  1487604609             MURFREESBORO MEDICAL CLINIC
# 16           132458  1467460725     SOUTHERN RADIOLOGY ASSOCIATES, PLLC
# 17           132087  1861479545                 MAURY REGIONAL HOSPITAL
# 18           128895  1538153937       TENNESSEE ORTHOPAEDIC ALLIANCE PA
# 19           113787  1912953381     CARDIOVASCULAR ANESTHESIOLOGISTS PC

# %%
# Find competitor hosptitals with the largest number of total referrals.
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT SUM(transaction_count) AS total_referrals, to_npi, n.provider_org_name, t.classification
    FROM filtered_hop_teaming AS f
    JOIN npidata AS n
    ON f.to_npi = n.npi
    JOIN taxonomy AS t
    USING(taxonomy_code)
    WHERE classification = 'Family Medicine'
    GROUP BY to_npi, provider_org_name
    --HAVING provider_org_name LIKE '%VUMC%'
    ORDER BY total_referrals DESC
    LIMIT 50;
    """ 
    
    test = pd.read_sql(query, db)

test

# %%
# Find competitor hosptitals with the largest number of total referrals.
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT classification, SUM(transaction_count)
    FROM filtered_hop_teaming AS f
    JOIN npidata AS n
    ON f.to_npi = n.npi
    JOIN taxonomy AS t
    USING(taxonomy_code)
    --WHERE provider_org_name LIKE '%VANDERBILT%'
    GROUP BY classification
    ORDER BY SUM(transaction_count) DESC;
    """ 
    
    test = pd.read_sql(query, db)

test

# %%
# Find addresses of all Vanderbilt locations
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT *
    FROM npidata
    WHERE provider_org_name LIKE '%VANDERBILT%'
    GROUP BY provider_business_address_1
        , provider_business_city
        , provider_business_state
        , provider_business_zip5
    """ 
    
    test = pd.read_sql(query, db)

test

# %%
# Find competitor hosptitals with the largest number of total referrals.
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    WITH vandy_address AS (
        SELECT *
        FROM npidata
        WHERE provider_org_name LIKE '%VANDERBILT%'
        GROUP BY provider_business_address_1
            , provider_business_city
            , provider_business_state
            , provider_business_zip5
    )
    SELECT *
    FROM npidata
    --JOIN vandy_address AS va USING(npi)
    WHERE provider_org_name NOT LIKE '%VANDERBILT%'
    AND provider_business_address_1 IN (SELECT provider_business_address_1 FROM vandy_address)
    AND provider_business_city IN (SELECT provider_business_city FROM vandy_address)
    AND provider_business_zip5 IN (SELECT provider_business_zip5 FROM vandy_address)
    """ 
    
    test = pd.read_sql(query, db)

test

# %%
# TESTING SQUARE
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT provider_business_state, COUNT(provider_business_state)
    FROM npidata
    GROUP BY provider_business_state
    """ 
    
    test = pd.read_sql(query, db)

test

# %%
# TESTING SQUARE
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT *
    FROM npidata
    LIMIT 1;
    """ 
    
    test = pd.read_sql(query, db)

test

# %%
# Tingting's code for exporting to Neo4j

nodes = list(set(ht.from_npi.tolist() + ht.to_npi.tolist()))
node_df = pd.DataFrame({'npi:ID': nodes})
node_df[':LABEL'] = "Provider"
node_df.to_csv('import/nodes.csv', index = False)
edges = pd.DataFrame({':START_ID' : ht.from_npi, 'patient_count': ht.patient_count, 
                      'transaction_count': ht.transaction_count, 
                     ':END_ID' : ht.to_npi})
edges[':TYPE'] = 'REFERRED_TO'
edges.to_csv('import/edges.csv', index = False)

# %%
# Test to confirm the tables loaded.
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT *
    FROM taxonomy
    LIMIT 1;
    """ 
    
    test = pd.read_sql(query, db)

test

# %%
# Test to confirm the tables loaded.
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT DISTINCT classification
    FROM taxonomy
    """ 
    
    test = pd.read_sql(query, db)

test

# %%
# Test to confirm the tables loaded.
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT npidata.*
    FROM npidata
    JOIN taxonomy USING (taxonomy_code)
    WHERE classification = 'train'
    """ 
    
    test = pd.read_sql(query, db)

test

# %%
referrals = pd.read_csv('../data/nashville_referrals_normalised.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
referrals.head(10)
# Out:
#    Unnamed: 0     index    from_npi      to_npi  patient_count  \
# 0           0  20662650  1780832899  1245233220             62
# 1           1  16742214  1851362628  1790788040             26
# 2           2   6532675  1396753356  1609879956             27
# 3           3  18197644  1144264458  1609879956             36
# 4           4  26837443  1942347513  1609879956             36
# 5           5    832492  1003833872  1568464873             49
# 6           6    832494  1003858267  1568464873             50
# 7           7    832495  1003862566  1568464873             91
# 8           8    832497  1013226026  1568464873            165
# 9           9    832499  1003991167  1568464873             35
#
#    transaction_count  average_day_wait  std_day_wait  from_zip  \
# 0                 63             2.667        20.412     37203
# 1                 65             3.231        18.277     37129
# 2                 68             4.529        27.525     37174
# 3                 77             3.247        27.359     37067
# 4                 53            21.509        40.591     37217
# 5                117            19.983        26.492     37055
# 6                 63            17.698        34.482     37055
# 7                 94            42.968        47.179     37072
# 8                239            42.209        54.333     37055
# 9                 67            21.940        24.913     37203
#
#    from_npi_specialty  from_entity_type_code  to_zip  \
# 0      Anesthesiology                    1.0   37115
# 1   Internal Medicine                    1.0   37129
# 2   Internal Medicine                    1.0   37214
# 3     Family Medicine                    1.0   37214
# 4  Nurse Practitioner                    1.0   37214
# 5           Counselor                    1.0   37055
# 6         Hospitalist                    1.0   37055
# 7           Radiology                    1.0   37055
# 8  Nurse Practitioner                    1.0   37055
# 9       Ophthalmology                    1.0   37055
#
#                 to_npi_specialty  to_entity_type_code to_facility  \
# 0                  Clinic/Center                  2.0         NaN
# 1  Hospice Care, Community Based                  2.0         NaN
# 2  Hospice Care, Community Based                  2.0         NaN
# 3  Hospice Care, Community Based                  2.0         NaN
# 4  Hospice Care, Community Based                  2.0         NaN
# 5                Family Medicine                  2.0         NaN
# 6                Family Medicine                  2.0         NaN
# 7                Family Medicine                  2.0         NaN
# 8                Family Medicine                  2.0         NaN
# 9                Family Medicine                  2.0         NaN
#
#   to_facility_group to_facility_name_normalised
# 0               NaN                         NaN
# 1               NaN                         NaN
# 2               NaN                         NaN
# 3               NaN                         NaN
# 4               NaN                         NaN
# 5               NaN                         NaN
# 6               NaN                         NaN
# 7               NaN                         NaN
# 8               NaN                         NaN
# 9               NaN                         NaN
