# %%
import pandas as pd
from dask import dataframe as dd
import numpy as np
import databricks.koalas as ks
from pyspark.sql import SparkSession
# Out:
# WARNING:root:'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. Koalas will set it for you but it does not work if there is a Spark context already launched.

# %%
npidata_raw = dd.read_csv('data/npidata_pfile_20050523-20210207.csv',low_memory =False,
                         dtype={'Healthcare Provider Primary Taxonomy Switch_11': 'object',
       'NPI': 'object','Entity Type Code' :'object',
        'Healthcare Provider Primary Taxonomy Switch_12': 'object',
       'Healthcare Provider Primary Taxonomy Switch_13': 'object',
       'Healthcare Provider Primary Taxonomy Switch_14': 'object',
       'Healthcare Provider Primary Taxonomy Switch_15': 'object',
       'Healthcare Provider Taxonomy Code_11': 'object',
       'Healthcare Provider Taxonomy Code_12': 'object',
       'Healthcare Provider Taxonomy Code_13': 'object',
       'Healthcare Provider Taxonomy Code_14': 'object',
       'Healthcare Provider Taxonomy Code_15': 'object',
       'Healthcare Provider Taxonomy Group_11': 'object',
       'Healthcare Provider Taxonomy Group_12': 'object',
       'Healthcare Provider Taxonomy Group_13': 'object',
       'Healthcare Provider Taxonomy Group_14': 'object',
       'Healthcare Provider Taxonomy Group_15': 'object',
       'Other Provider Identifier Issuer_16': 'object',
       'Other Provider Identifier Issuer_17': 'object',
       'Other Provider Identifier Issuer_18': 'object',
       'Other Provider Identifier Issuer_19': 'object',
       'Other Provider Identifier Issuer_20': 'object',
       'Other Provider Identifier Issuer_21': 'object',
       'Other Provider Identifier Issuer_22': 'object',
       'Other Provider Identifier Issuer_23': 'object',
       'Other Provider Identifier Issuer_24': 'object',
       'Other Provider Identifier Issuer_25': 'object',
       'Other Provider Identifier Issuer_26': 'object',
       'Other Provider Identifier Issuer_27': 'object',
       'Other Provider Identifier Issuer_28': 'object',
       'Other Provider Identifier Issuer_29': 'object',
        'Other Provider Identifier_31':'object',
'Other Provider Identifier_32': 'object', 
'Other Provider Identifier_33': 'object', 'Other Provider Identifier_38':'object',
       'Other Provider Identifier State_16': 'object',
       'Other Provider Identifier State_17': 'object',
       'Other Provider Identifier State_18': 'object',
       'Other Provider Identifier State_19': 'object',
       'Other Provider Identifier State_20': 'object',
       'Other Provider Identifier State_21': 'object',
       'Other Provider Identifier State_22': 'object',
       'Other Provider Identifier State_23': 'object',
       'Other Provider Identifier State_24': 'object',
       'Other Provider Identifier State_25': 'object',
       'Other Provider Identifier State_26': 'object',
       'Other Provider Identifier State_27': 'object',
       'Other Provider Identifier State_28': 'object',
       'Other Provider Identifier State_29': 'object',
       'Other Provider Identifier State_30': 'object',
       'Other Provider Identifier State_31': 'object',
       'Other Provider Identifier State_32': 'object',
       'Other Provider Identifier State_33': 'object',
       'Other Provider Identifier State_34': 'object',
       'Other Provider Identifier State_35': 'object',
       'Other Provider Identifier State_36': 'object',
       'Other Provider Identifier State_37': 'object',
       'Other Provider Identifier State_38': 'object',
       'Other Provider Identifier State_39': 'object',
       'Other Provider Identifier State_40': 'object',
       'Other Provider Identifier State_41': 'object',
       'Other Provider Identifier State_42': 'object',
       'Other Provider Identifier State_43': 'object',
       'Other Provider Identifier State_44': 'object',
       'Other Provider Identifier State_45': 'object',
       'Other Provider Identifier State_46': 'object',
       'Other Provider Identifier State_47': 'object',
       'Other Provider Identifier_10': 'object',
       'Other Provider Identifier_13': 'object',
       'Other Provider Identifier_14': 'object',
       'Other Provider Identifier_15': 'object',
       'Other Provider Identifier_16': 'object',
       'Other Provider Identifier_17': 'object',
       'Other Provider Identifier_18': 'object',
       'Other Provider Identifier_19': 'object',
       'Other Provider Identifier_20': 'object',
       'Other Provider Identifier_21': 'object',
       'Other Provider Identifier_22': 'object',
       'Other Provider Identifier_23': 'object',
       'Other Provider Identifier_24': 'object',
       'Other Provider Identifier_25': 'object',
       'Other Provider Identifier_26': 'object',
       'Other Provider Identifier_27': 'object',
       'Other Provider Identifier_28': 'object',
       'Other Provider Identifier_29': 'object',
       'Other Provider Identifier_30': 'object',
       'Other Provider Identifier_34': 'object',
       'Other Provider Identifier_35': 'object',
       'Other Provider Identifier_36': 'object',
       'Other Provider Identifier_39': 'object',
       'Other Provider Identifier_40': 'object',
       'Other Provider Identifier_44': 'object',
       'Other Provider Identifier_45': 'object',
       'Provider Business Mailing Address Postal Code': 'object',
       'Provider Business Practice Location Address Telephone Number': 'object',
       'Provider Business Practice Location Address Postal Code': 'object',
       'Provider License Number State Code_11': 'object',
       'Provider License Number State Code_12': 'object',
       'Provider License Number State Code_13': 'object',
       'Provider License Number State Code_14': 'object',
       'Provider License Number State Code_15': 'object',
       'Provider License Number State Code_6': 'object',
       'Provider License Number State Code_8': 'object',
       'Provider License Number_11': 'object',
       'Provider License Number_12': 'object',
       'Provider License Number_13': 'object',
       'Provider License Number_14': 'object',
       'Provider License Number_15': 'object',
       'Provider License Number_5': 'object',
       'Provider License Number_6': 'object',
       'Provider License Number_8': 'object',
       'Provider Other Name Suffix Text': 'object',
                               'Authorized Official Telephone Number': 'object',
       'Other Provider Identifier Issuer_30': 'object',
       'Other Provider Identifier Issuer_31': 'object',
       'Other Provider Identifier Issuer_32': 'object',
       'Other Provider Identifier Issuer_33': 'object',
       'Other Provider Identifier Issuer_34': 'object',
       'Other Provider Identifier Issuer_35': 'object',
       'Other Provider Identifier Issuer_36': 'object',
       'Other Provider Identifier Issuer_41': 'object',
       'Other Provider Identifier State_48': 'object',
       'Other Provider Identifier_41': 'object',
       'Other Provider Identifier_47': 'object',
       'Other Provider Identifier_48': 'object',
       'Provider Business Mailing Address Fax Number': 'object',
       'Provider Business Practice Location Address Fax Number': 'object',
                               'Other Provider Identifier Issuer_37': 'object',
       'Other Provider Identifier Issuer_38': 'object',
       'Other Provider Identifier Issuer_39': 'object',
       'Other Provider Identifier Issuer_40': 'object',
            'Other Provider Identifier Issuer_42': 'object',
       'Other Provider Identifier Issuer_43': 'object',
       'Other Provider Identifier Issuer_44': 'object',
       'Other Provider Identifier Issuer_45': 'object',
       'Other Provider Identifier Issuer_46': 'object',
       'Other Provider Identifier Issuer_47': 'object',
       'Other Provider Identifier Issuer_48': 'object',
       'Other Provider Identifier Issuer_49': 'object',
       'Other Provider Identifier_49': 'object','Other Provider Identifier_42': 'object',
        'Other Provider Identifier_37': 'object',
       'Other Provider Identifier_43': 'object',
       'Other Provider Identifier_46': 'object',
    'Other Provider Identifier Issuer_50': 'object',
       'Other Provider Identifier State_49': 'object',
       'Other Provider Identifier State_50': 'object',
                                'Other Provider Identifier_50': 'object'
                               }
                         )

# %%
npidata  = npidata_raw[['NPI','Entity Type Code','Provider Organization Name (Legal Business Name)',
                               'Provider Last Name (Legal Name)','Provider First Name',
            'Provider Middle Name','Provider Name Prefix Text','Provider Name Suffix Text',
                'Provider Credential Text','Provider First Line Business Mailing Address',
                'Provider Second Line Business Mailing Address','Provider Business Mailing Address City Name',
         'Provider Business Mailing Address State Name','Provider Business Mailing Address Postal Code']]

# %%
npidata.columns = npidata.columns.str.replace(' ', '')

# %%
npidata.head()
# Out:
#           NPI EntityTypeCode ProviderOrganizationName(LegalBusinessName)  \
# 0  1679576722              1                                         NaN
# 1  1588667638              1                                         NaN
# 2  1497758544              2      CUMBERLAND COUNTY HOSPITAL SYSTEM, INC
# 3  1306849450              1                                         NaN
# 4  1215930367              1                                         NaN
#
#   ProviderLastName(LegalName) ProviderFirstName ProviderMiddleName  \
# 0                       WIEBE             DAVID                  A
# 1                     PILCHER           WILLIAM                  C
# 2                         NaN               NaN                NaN
# 3                     SMITSON            HAROLD              LEROY
# 4                     GRESSOT           LAURENT                NaN
#
#   ProviderNamePrefixText ProviderNameSuffixText ProviderCredentialText  \
# 0                    NaN                    NaN                   M.D.
# 1                    DR.                    NaN                     MD
# 2                    NaN                    NaN                    NaN
# 3                    DR.                     II                   M.D.
# 4                    DR.                    NaN                   M.D.
#
#   ProviderFirstLineBusinessMailingAddress  \
# 0                             PO BOX 2168
# 1                        1824 KING STREET
# 2                         3418 VILLAGE DR
# 3                            810 LUCAS DR
# 4                        17323 RED OAK DR
#
#   ProviderSecondLineBusinessMailingAddress  \
# 0                                      NaN
# 1                                SUITE 300
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   ProviderBusinessMailingAddressCityName  \
# 0                                KEARNEY
# 1                           JACKSONVILLE
# 2                           FAYETTEVILLE
# 3                                 ATHENS
# 4                                HOUSTON
#
#   ProviderBusinessMailingAddressStateName  \
# 0                                      NE
# 1                                      FL
# 2                                      NC
# 3                                      TX
# 4                                      TX
#
#   ProviderBusinessMailingAddressPostalCode
# 0                                688482168
# 1                                322044736
# 2                                283044552
# 3                                757513446
# 4                                770901243

# %%
npidata.compute()
# Out:
#               NPI EntityTypeCode ProviderOrganizationName(LegalBusinessName)  \
# 0      1679576722              1                                         NaN
# 1      1588667638              1                                         NaN
# 2      1497758544              2      CUMBERLAND COUNTY HOSPITAL SYSTEM, INC
# 3      1306849450              1                                         NaN
# 4      1215930367              1                                         NaN
# ...           ...            ...                                         ...
# 51453  1326630724              1                                         NaN
# 51454  1912599325              1                                         NaN
# 51455  1821680232              1                                         NaN
# 51456  1730771148              1                                         NaN
# 51457  1649862053              2     HAPPY SPEECH AND LANGUAGE SERVICES, LLC
#
#       ProviderLastName(LegalName) ProviderFirstName ProviderMiddleName  \
# 0                           WIEBE             DAVID                  A
# 1                         PILCHER           WILLIAM                  C
# 2                             NaN               NaN                NaN
# 3                         SMITSON            HAROLD              LEROY
# 4                         GRESSOT           LAURENT                NaN
# ...                           ...               ...                ...
# 51453                    DELMONTE            ROXANA                NaN
# 51454                     KATEHIS          GIORGIOS                NaN
# 51455           NGANDJO YEPNDJOUO          SARIETTE                NaN
# 51456                       JONES          JEANETTE              MARIE
# 51457                         NaN               NaN                NaN
#
#       ProviderNamePrefixText ProviderNameSuffixText ProviderCredentialText  \
# 0                        NaN                    NaN                   M.D.
# 1                        DR.                    NaN                     MD
# 2                        NaN                    NaN                    NaN
# 3                        DR.                     II                   M.D.
# 4                        DR.                    NaN                   M.D.
# ...                      ...                    ...                    ...
# 51453                    NaN                    NaN         MSN-APRN-FNP-C
# 51454                    NaN                    NaN                 PHARMD
# 51455                    MS.                    NaN                    NaN
# 51456                    NaN                    NaN                    NaN
# 51457                    NaN                    NaN                    NaN
#
#       ProviderFirstLineBusinessMailingAddress  \
# 0                                 PO BOX 2168
# 1                            1824 KING STREET
# 2                             3418 VILLAGE DR
# 3                                810 LUCAS DR
# 4                            17323 RED OAK DR
# ...                                       ...
# 51453         8895 FONTAINEBLEAU BLVD APT 309
# 51454                          19 SHERMAN AVE
# 51455             2268 CENTURY POINT LN APT E
# 51456                              412 1ST ST
# 51457                 5218 PRAIRIE TERRACE LN
#
#       ProviderSecondLineBusinessMailingAddress  \
# 0                                          NaN
# 1                                    SUITE 300
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 51453                                      NaN
# 51454                                      NaN
# 51455                                      NaN
# 51456                                      NaN
# 51457                                      NaN
#
#       ProviderBusinessMailingAddressCityName  \
# 0                                    KEARNEY
# 1                               JACKSONVILLE
# 2                               FAYETTEVILLE
# 3                                     ATHENS
# 4                                    HOUSTON
# ...                                      ...
# 51453                                  MIAMI
# 51454                              PLAINVIEW
# 51455                       GLENDALE HEIGHTS
# 51456                              MIDDLESEX
# 51457                               FULSHEAR
#
#       ProviderBusinessMailingAddressStateName  \
# 0                                          NE
# 1                                          FL
# 2                                          NC
# 3                                          TX
# 4                                          TX
# ...                                       ...
# 51453                                      FL
# 51454                                      NY
# 51455                                      IL
# 51456                                      NJ
# 51457                                      TX
#
#       ProviderBusinessMailingAddressPostalCode
# 0                                    688482168
# 1                                    322044736
# 2                                    283044552
# 3                                    757513446
# 4                                    770901243
# ...                                        ...
# 51453                                331724443
# 51454                                118035228
# 51455                                601391672
# 51456                                088461502
# 51457                                774412199
#
# [6714038 rows x 14 columns]

# %%
npidata.to_csv('npidata.csv',single_file = True)
# Out:
# ['C:/Users/matth/Downloads/hop_project/Practice_hop/npidata.csv']

# %%
npidata.head()
# Out:
#           NPI EntityTypeCode ProviderOrganizationName(LegalBusinessName)  \
# 0  1679576722              1                                         NaN
# 1  1588667638              1                                         NaN
# 2  1497758544              2      CUMBERLAND COUNTY HOSPITAL SYSTEM, INC
# 3  1306849450              1                                         NaN
# 4  1215930367              1                                         NaN
#
#   ProviderLastName(LegalName) ProviderFirstName ProviderMiddleName  \
# 0                       WIEBE             DAVID                  A
# 1                     PILCHER           WILLIAM                  C
# 2                         NaN               NaN                NaN
# 3                     SMITSON            HAROLD              LEROY
# 4                     GRESSOT           LAURENT                NaN
#
#   ProviderNamePrefixText ProviderNameSuffixText ProviderCredentialText  \
# 0                    NaN                    NaN                   M.D.
# 1                    DR.                    NaN                     MD
# 2                    NaN                    NaN                    NaN
# 3                    DR.                     II                   M.D.
# 4                    DR.                    NaN                   M.D.
#
#   ProviderFirstLineBusinessMailingAddress  \
# 0                             PO BOX 2168
# 1                        1824 KING STREET
# 2                         3418 VILLAGE DR
# 3                            810 LUCAS DR
# 4                        17323 RED OAK DR
#
#   ProviderSecondLineBusinessMailingAddress  \
# 0                                      NaN
# 1                                SUITE 300
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   ProviderBusinessMailingAddressCityName  \
# 0                                KEARNEY
# 1                           JACKSONVILLE
# 2                           FAYETTEVILLE
# 3                                 ATHENS
# 4                                HOUSTON
#
#   ProviderBusinessMailingAddressStateName  \
# 0                                      NE
# 1                                      FL
# 2                                      NC
# 3                                      TX
# 4                                      TX
#
#   ProviderBusinessMailingAddressPostalCode
# 0                                688482168
# 1                                322044736
# 2                                283044552
# 3                                757513446
# 4                                770901243

# %%
npidata.compute()
# Out:
#               NPI Entity Type Code  \
# 0      1679576722                1
# 1      1588667638                1
# 2      1497758544                2
# 3      1306849450                1
# 4      1215930367                1
# ...           ...              ...
# 51453  1326630724                1
# 51454  1912599325                1
# 51455  1821680232                1
# 51456  1730771148                1
# 51457  1649862053                2
#
#       Provider Organization Name (Legal Business Name)  \
# 0                                                  NaN
# 1                                                  NaN
# 2               CUMBERLAND COUNTY HOSPITAL SYSTEM, INC
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 51453                                              NaN
# 51454                                              NaN
# 51455                                              NaN
# 51456                                              NaN
# 51457          HAPPY SPEECH AND LANGUAGE SERVICES, LLC
#
#       Provider Last Name (Legal Name) Provider First Name  \
# 0                               WIEBE               DAVID
# 1                             PILCHER             WILLIAM
# 2                                 NaN                 NaN
# 3                             SMITSON              HAROLD
# 4                             GRESSOT             LAURENT
# ...                               ...                 ...
# 51453                        DELMONTE              ROXANA
# 51454                         KATEHIS            GIORGIOS
# 51455               NGANDJO YEPNDJOUO            SARIETTE
# 51456                           JONES            JEANETTE
# 51457                             NaN                 NaN
#
#       Provider Middle Name Provider Name Prefix Text  \
# 0                        A                       NaN
# 1                        C                       DR.
# 2                      NaN                       NaN
# 3                    LEROY                       DR.
# 4                      NaN                       DR.
# ...                    ...                       ...
# 51453                  NaN                       NaN
# 51454                  NaN                       NaN
# 51455                  NaN                       MS.
# 51456                MARIE                       NaN
# 51457                  NaN                       NaN
#
#       Provider Name Suffix Text Provider Credential Text  \
# 0                           NaN                     M.D.
# 1                           NaN                       MD
# 2                           NaN                      NaN
# 3                            II                     M.D.
# 4                           NaN                     M.D.
# ...                         ...                      ...
# 51453                       NaN           MSN-APRN-FNP-C
# 51454                       NaN                   PHARMD
# 51455                       NaN                      NaN
# 51456                       NaN                      NaN
# 51457                       NaN                      NaN
#
#       Provider First Line Business Mailing Address  \
# 0                                      PO BOX 2168
# 1                                 1824 KING STREET
# 2                                  3418 VILLAGE DR
# 3                                     810 LUCAS DR
# 4                                 17323 RED OAK DR
# ...                                            ...
# 51453              8895 FONTAINEBLEAU BLVD APT 309
# 51454                               19 SHERMAN AVE
# 51455                  2268 CENTURY POINT LN APT E
# 51456                                   412 1ST ST
# 51457                      5218 PRAIRIE TERRACE LN
#
#       Provider Second Line Business Mailing Address  \
# 0                                               NaN
# 1                                         SUITE 300
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 51453                                           NaN
# 51454                                           NaN
# 51455                                           NaN
# 51456                                           NaN
# 51457                                           NaN
#
#       Provider Business Mailing Address City Name  \
# 0                                         KEARNEY
# 1                                    JACKSONVILLE
# 2                                    FAYETTEVILLE
# 3                                          ATHENS
# 4                                         HOUSTON
# ...                                           ...
# 51453                                       MIAMI
# 51454                                   PLAINVIEW
# 51455                            GLENDALE HEIGHTS
# 51456                                   MIDDLESEX
# 51457                                    FULSHEAR
#
#       Provider Business Mailing Address State Name  \
# 0                                               NE
# 1                                               FL
# 2                                               NC
# 3                                               TX
# 4                                               TX
# ...                                            ...
# 51453                                           FL
# 51454                                           NY
# 51455                                           IL
# 51456                                           NJ
# 51457                                           TX
#
#       Provider Business Mailing Address Postal Code
# 0                                         688482168
# 1                                         322044736
# 2                                         283044552
# 3                                         757513446
# 4                                         770901243
# ...                                             ...
# 51453                                     331724443
# 51454                                     118035228
# 51455                                     601391672
# 51456                                     088461502
# 51457                                     774412199
#
# [6714038 rows x 14 columns]

# %%
npi_taxonomy= npidata_raw[['NPI',
    'Healthcare Provider Primary Taxonomy Switch_1','Healthcare Provider Primary Taxonomy Switch_2',
    'Healthcare Provider Primary Taxonomy Switch_3','Healthcare Provider Primary Taxonomy Switch_4',
    'Healthcare Provider Primary Taxonomy Switch_5','Healthcare Provider Primary Taxonomy Switch_6',
    'Healthcare Provider Primary Taxonomy Switch_7','Healthcare Provider Primary Taxonomy Switch_8',
    'Healthcare Provider Primary Taxonomy Switch_9','Healthcare Provider Primary Taxonomy Switch_9',
    'Healthcare Provider Primary Taxonomy Switch_10','Healthcare Provider Primary Taxonomy Switch_11',
    'Healthcare Provider Primary Taxonomy Switch_12','Healthcare Provider Primary Taxonomy Switch_13',
    'Healthcare Provider Primary Taxonomy Switch_14','Healthcare Provider Primary Taxonomy Switch_15',
     'Healthcare Provider Taxonomy Code_1','Healthcare Provider Taxonomy Code_2',
    'Healthcare Provider Taxonomy Code_3','Healthcare Provider Taxonomy Code_4','Healthcare Provider Taxonomy Code_5',
    'Healthcare Provider Taxonomy Code_6','Healthcare Provider Taxonomy Code_7',
    'Healthcare Provider Taxonomy Code_8','Healthcare Provider Taxonomy Code_9',
    'Healthcare Provider Taxonomy Code_10','Healthcare Provider Taxonomy Code_11',
    'Healthcare Provider Taxonomy Code_12','Healthcare Provider Taxonomy Code_13',
    'Healthcare Provider Taxonomy Code_14','Healthcare Provider Taxonomy Code_15'                     
                        ]]

# %%
npi_taxonomy.head()
# Out:
#           NPI Healthcare Provider Primary Taxonomy Switch_1  \
# 0  1679576722                                             Y
# 1  1588667638                                             N
# 2  1497758544                                             Y
# 3  1306849450                                             Y
# 4  1215930367                                             N
#
#   Healthcare Provider Primary Taxonomy Switch_2  \
# 0                                           NaN
# 1                                             Y
# 2                                           NaN
# 3                                           NaN
# 4                                             Y
#
#   Healthcare Provider Primary Taxonomy Switch_3  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Healthcare Provider Primary Taxonomy Switch_4  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Healthcare Provider Primary Taxonomy Switch_5  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Healthcare Provider Primary Taxonomy Switch_6  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Healthcare Provider Primary Taxonomy Switch_7  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Healthcare Provider Primary Taxonomy Switch_8  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Healthcare Provider Primary Taxonomy Switch_9  ...  \
# 0                                           NaN  ...
# 1                                           NaN  ...
# 2                                           NaN  ...
# 3                                           NaN  ...
# 4                                           NaN  ...
#
#   Healthcare Provider Taxonomy Code_6 Healthcare Provider Taxonomy Code_7  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#   Healthcare Provider Taxonomy Code_8 Healthcare Provider Taxonomy Code_9  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#   Healthcare Provider Taxonomy Code_10 Healthcare Provider Taxonomy Code_11  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#   Healthcare Provider Taxonomy Code_12 Healthcare Provider Taxonomy Code_13  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#   Healthcare Provider Taxonomy Code_14 Healthcare Provider Taxonomy Code_15
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
# [5 rows x 32 columns]

# %%
npi_tax_switch= npidata_raw[['NPI',
    'Healthcare Provider Primary Taxonomy Switch_1','Healthcare Provider Primary Taxonomy Switch_2',
    'Healthcare Provider Primary Taxonomy Switch_3','Healthcare Provider Primary Taxonomy Switch_4',
    'Healthcare Provider Primary Taxonomy Switch_5','Healthcare Provider Primary Taxonomy Switch_6',
    'Healthcare Provider Primary Taxonomy Switch_7','Healthcare Provider Primary Taxonomy Switch_8',
    'Healthcare Provider Primary Taxonomy Switch_9','Healthcare Provider Primary Taxonomy Switch_9',
    'Healthcare Provider Primary Taxonomy Switch_10','Healthcare Provider Primary Taxonomy Switch_11',
    'Healthcare Provider Primary Taxonomy Switch_12','Healthcare Provider Primary Taxonomy Switch_13',
    'Healthcare Provider Primary Taxonomy Switch_14','Healthcare Provider Primary Taxonomy Switch_15' 
]]

# %%
dfmelt_switch = npi_tax_switch.melt(id_vars=['NPI'], var_name='primary_taxonomy_switch')

# %%
# Only keep the primary taxonomy
dfmelt_switch = dfmelt_switch[dfmelt_switch['value'] == 'Y']

# %%
dfmelt_switch=dfmelt_switch.rename(columns = {'value':'switch_value'})
dfmelt_switch.head()
# Out:
#           NPI                        primary_taxonomy_switch switch_value
# 0  1679576722  Healthcare Provider Primary Taxonomy Switch_1            Y
# 2  1497758544  Healthcare Provider Primary Taxonomy Switch_1            Y
# 3  1306849450  Healthcare Provider Primary Taxonomy Switch_1            Y
# 5  1023011178  Healthcare Provider Primary Taxonomy Switch_1            Y
# 6  1932102084  Healthcare Provider Primary Taxonomy Switch_1            Y

# %%
dfmelt_switch=dfmelt_switch.compute()

# %%
dfmelt_switch.head()
# Out:
#           NPI                        primary_taxonomy_switch switch_value
# 0  1679576722  Healthcare Provider Primary Taxonomy Switch_1            Y
# 2  1497758544  Healthcare Provider Primary Taxonomy Switch_1            Y
# 3  1306849450  Healthcare Provider Primary Taxonomy Switch_1            Y
# 5  1023011178  Healthcare Provider Primary Taxonomy Switch_1            Y
# 6  1932102084  Healthcare Provider Primary Taxonomy Switch_1            Y

# %%
dfmelt_switch.to_csv('taxonomy_switch.csv',single_file=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-605dca8b65bb> in <module>
# ----> 1 dfmelt_switch.to_csv('taxonomy_switch.csv',single_file=True)
#
# TypeError: to_csv() got an unexpected keyword argument 'single_file'

# %%
npi_tax_code =npidata_raw[[
    'NPI','Healthcare Provider Taxonomy Code_1','Healthcare Provider Taxonomy Code_2',
    'Healthcare Provider Taxonomy Code_3','Healthcare Provider Taxonomy Code_4','Healthcare Provider Taxonomy Code_5',
    'Healthcare Provider Taxonomy Code_6','Healthcare Provider Taxonomy Code_7',
    'Healthcare Provider Taxonomy Code_8','Healthcare Provider Taxonomy Code_9',
    'Healthcare Provider Taxonomy Code_10','Healthcare Provider Taxonomy Code_11',
    'Healthcare Provider Taxonomy Code_12','Healthcare Provider Taxonomy Code_13',
    'Healthcare Provider Taxonomy Code_14','Healthcare Provider Taxonomy Code_15']]

# %%
npi_tax_code_melt = npi_tax_code.melt(id_vars=['NPI'], var_name='primary_taxonomy_code')

# %%
npi_tax_code_melt=npi_tax_code_melt.rename(columns = {'value':'code_value'})

# %%
npi_tax_code_melt
# Out:
# Dask DataFrame Structure:
#                     NPI primary_taxonomy_code code_value
# npartitions=126
#                  object                object     object
#                     ...                   ...        ...
# ...                 ...                   ...        ...
#                     ...                   ...        ...
#                     ...                   ...        ...
# Dask Name: rename, 504 tasks

# %%
npi_tax_code_melt = npi_tax_code_melt.merge(dfmelt_switch, how='inner', on='NPI')

# %%
npi_tax_code_melt
# Out:
# Dask DataFrame Structure:
#                     NPI primary_taxonomy_code code_value primary_taxonomy_switch switch_value
# npartitions=126
#                  object                object     object                  object       object
#                     ...                   ...        ...                     ...          ...
# ...                 ...                   ...        ...                     ...          ...
#                     ...                   ...        ...                     ...          ...
#                     ...                   ...        ...                     ...          ...
# Dask Name: merge, 631 tasks

# %%
npi_tax_code_melt.compute()
# Out:
#                NPI                 primary_taxonomy_code  code_value  \
# 0       1679576722   Healthcare Provider Taxonomy Code_1  207X00000X
# 1       1679576722   Healthcare Provider Taxonomy Code_2         NaN
# 2       1679576722   Healthcare Provider Taxonomy Code_3         NaN
# 3       1679576722   Healthcare Provider Taxonomy Code_4         NaN
# 4       1679576722   Healthcare Provider Taxonomy Code_5         NaN
# ...            ...                                   ...         ...
# 770695  1649862053  Healthcare Provider Taxonomy Code_11         NaN
# 770696  1649862053  Healthcare Provider Taxonomy Code_12         NaN
# 770697  1649862053  Healthcare Provider Taxonomy Code_13         NaN
# 770698  1649862053  Healthcare Provider Taxonomy Code_14         NaN
# 770699  1649862053  Healthcare Provider Taxonomy Code_15         NaN
#
#                               primary_taxonomy_switch switch_value
# 0       Healthcare Provider Primary Taxonomy Switch_1            Y
# 1       Healthcare Provider Primary Taxonomy Switch_1            Y
# 2       Healthcare Provider Primary Taxonomy Switch_1            Y
# 3       Healthcare Provider Primary Taxonomy Switch_1            Y
# 4       Healthcare Provider Primary Taxonomy Switch_1            Y
# ...                                               ...          ...
# 770695  Healthcare Provider Primary Taxonomy Switch_1            Y
# 770696  Healthcare Provider Primary Taxonomy Switch_1            Y
# 770697  Healthcare Provider Primary Taxonomy Switch_1            Y
# 770698  Healthcare Provider Primary Taxonomy Switch_1            Y
# 770699  Healthcare Provider Primary Taxonomy Switch_1            Y
#
# [97237140 rows x 5 columns]

# %%
npi_tax_code_melt.head()
# Out:
#           NPI                primary_taxonomy_code  code_value  \
# 0  1679576722  Healthcare Provider Taxonomy Code_1  207X00000X
# 1  1679576722  Healthcare Provider Taxonomy Code_2         NaN
# 2  1679576722  Healthcare Provider Taxonomy Code_3         NaN
# 3  1679576722  Healthcare Provider Taxonomy Code_4         NaN
# 4  1679576722  Healthcare Provider Taxonomy Code_5         NaN
#
#                          primary_taxonomy_switch switch_value
# 0  Healthcare Provider Primary Taxonomy Switch_1            Y
# 1  Healthcare Provider Primary Taxonomy Switch_1            Y
# 2  Healthcare Provider Primary Taxonomy Switch_1            Y
# 3  Healthcare Provider Primary Taxonomy Switch_1            Y
# 4  Healthcare Provider Primary Taxonomy Switch_1            Y

# %%
new_taxonomy_codes= npi_tax_code_melt[['NPI',
    'code_value']]

# %%
new_taxonomy_codes.dropna()
# Out:
# Dask DataFrame Structure:
#                     NPI code_value
# npartitions=126
#                  object     object
#                     ...        ...
# ...                 ...        ...
#                     ...        ...
#                     ...        ...
# Dask Name: dropna, 883 tasks

# %%
df=new_taxonomy_codes.dropna()

# %%
df.compute()
# Out:
#                NPI  code_value
# 0       1679576722  207X00000X
# 15      1588667638  207RC0000X
# 16      1588667638  207RC0000X
# 30      1497758544  251G00000X
# 45      1306849450  2085R0202X
# ...            ...         ...
# 770640  1912599325  183500000X
# 770655  1821680232  163WP0808X
# 770670  1730771148  2255A2300X
# 770671  1730771148  390200000X
# 770685  1649862053  235Z00000X
#
# [8079880 rows x 2 columns]

# %%
df.to_csv('npi_taxonomy_data.csv',single_file=True)
# Out:
# ['C:/Users/matth/Downloads/hop_project/Practice_hop/npi_taxonomy_data.csv']

# %%
npidata
# Out:
# Dask DataFrame Structure:
#                     NPI EntityTypeCode ProviderOrganizationName(LegalBusinessName) ProviderLastName(LegalName) ProviderFirstName ProviderMiddleName ProviderNamePrefixText ProviderNameSuffixText ProviderCredentialText ProviderFirstLineBusinessMailingAddress ProviderSecondLineBusinessMailingAddress ProviderBusinessMailingAddressCityName ProviderBusinessMailingAddressStateName ProviderBusinessMailingAddressPostalCode
# npartitions=126
#                  object         object                                      object                      object            object             object                 object                 object                 object                                  object                                   object                                 object                                  object                                   object
#                     ...            ...                                         ...                         ...               ...                ...                    ...                    ...                    ...                                     ...                                      ...                                    ...                                     ...                                      ...
# ...                 ...            ...                                         ...                         ...               ...                ...                    ...                    ...                    ...                                     ...                                      ...                                    ...                                     ...                                      ...
#                     ...            ...                                         ...                         ...               ...                ...                    ...                    ...                    ...                                     ...                                      ...                                    ...                                     ...                                      ...
#                     ...            ...                                         ...                         ...               ...                ...                    ...                    ...                    ...                                     ...                                      ...                                    ...                                     ...                                      ...
# Dask Name: rename, 504 tasks

# %%
df = df.merge(npidata, how='inner', on='NPI')

# %%
new_taxonomy_codes.head()
# Out:
#           NPI  code_value
# 0  1679576722  207X00000X
# 1  1679576722         NaN
# 2  1679576722         NaN
# 3  1679576722         NaN
# 4  1679576722         NaN

# %%
npi_tax_code_melt.to_csv('tax_code_switch.csv',single_file=True)
# Out:
# ['C:/Users/matth/Downloads/hop_project/Practice_hop/tax_code_switch.csv']

# %%
npi_tax_code_melt.compute()
dfmelt_switch=dfmelt_switch.compute()

# %%
npi_tax_code_melt.shape
# Out:
# (Delayed('int-af484473-0899-4f62-bb95-26b7fa3e47f3'), 3)

# %%
dfmelt_switch.shape
# Out:
# (Delayed('int-1e60be5c-c1f3-41e7-9412-2803351bf2ab'), 3)

# %%
dfmelt_code = dfmelt_code.merge(dfmelt_switch, how='inner', on='NPI')

# %%
dfmelt_code
# Out:
# Dask DataFrame Structure:
#                     NPI primary_taxonomy_code code_value primary_taxonomy_switch_x switch_value_x primary_taxonomy_switch_y switch_value_y primary_taxonomy_switch_x switch_value_x primary_taxonomy_switch_y switch_value_y primary_taxonomy_switch switch_value
# npartitions=126
#                  object                object     object                    object         object                    object         object                    object         object                    object         object                  object       object
#                     ...                   ...        ...                       ...            ...                       ...            ...                       ...            ...                       ...            ...                     ...          ...
# ...                 ...                   ...        ...                       ...            ...                       ...            ...                       ...            ...                       ...            ...                     ...          ...
#                     ...                   ...        ...                       ...            ...                       ...            ...                       ...            ...                       ...            ...                     ...          ...
#                     ...                   ...        ...                       ...            ...                       ...            ...                       ...            ...                       ...            ...                     ...          ...
# Dask Name: merge, 8965 tasks

# %%
dfmelt_switch.head()
# Out:
#           NPI                        primary_taxonomy_switch switch_value
# 0  1679576722  Healthcare Provider Primary Taxonomy Switch_1            Y
# 2  1497758544  Healthcare Provider Primary Taxonomy Switch_1            Y
# 3  1306849450  Healthcare Provider Primary Taxonomy Switch_1            Y
# 5  1023011178  Healthcare Provider Primary Taxonomy Switch_1            Y
# 6  1932102084  Healthcare Provider Primary Taxonomy Switch_1            Y

# %%
dfmelt_code.head()
# Out:
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,71,72,73,74,75,78,79,80,81,82,83,84,85,86,151,226,230,231,234,235,238,242,246,250,254,262,266,270,274,278,282,286,290,294,295,297,298,299,302,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,72,73,79,80,81,82,83,84,85,86,147,151,226,227,230,231,234,235,238,242,246,250,254,255,258,262,266,271,274,278,282,286,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-210-013f5bf34a87> in <module>
# ----> 1 dfmelt_code.head()
#
# ~\anaconda3\lib\site-packages\dask\dataframe\core.py in head(self, n, npartitions, compute)
#    1003             Whether to compute the result, default is True.
#    1004         """
# -> 1005         return self._head(n=n, npartitions=npartitions, compute=compute, safe=True)
#    1006
#    1007     def _head(self, n, npartitions, compute, safe):
#
# ~\anaconda3\lib\site-packages\dask\dataframe\core.py in _head(self, n, npartitions, compute, safe)
#    1036
#    1037         if compute:
# -> 1038             result = result.compute()
#    1039         return result
#    1040
#
# ~\anaconda3\lib\site-packages\dask\base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# ~\anaconda3\lib\site-packages\dask\base.py in compute(*args, **kwargs)
#     442         postcomputes.append(x.__dask_postcompute__())
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     446
#
# ~\anaconda3\lib\site-packages\dask\threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      74                 pools[thread][num_workers] = pool
#      75
# ---> 76     results = get_async(
#      77         pool.apply_async,
#      78         len(pool._pool),
#
# ~\anaconda3\lib\site-packages\dask\local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     484                         _execute_task(task, data)  # Re-execute locally
#     485                     else:
# --> 486                         raise_exception(exc, tb)
#     487                 res, worker_id = loads(res_info)
#     488                 state["cache"][key] = res
#
# ~\anaconda3\lib\site-packages\dask\local.py in reraise(exc, tb)
#     314     if exc.__traceback__ is not tb:
#     315         raise exc.with_traceback(tb)
# --> 316     raise exc
#     317
#     318
#
# ~\anaconda3\lib\site-packages\dask\local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     220     try:
#     221         task, data = loads(task_info)
# --> 222         result = _execute_task(task, data)
#     223         id = get_id()
#     224         result = dumps((result, id))
#
# ~\anaconda3\lib\site-packages\dask\core.py in _execute_task(arg, cache, dsk)
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# ~\anaconda3\lib\site-packages\dask\dataframe\io\csv.py in pandas_read_text(reader, b, header, kwargs, dtypes, columns, write_header, enforce, path)
#     149     df = reader(bio, **kwargs)
#     150     if dtypes:
# --> 151         coerce_dtypes(df, dtypes)
#     152
#     153     if enforce and columns and (list(df.columns) != list(columns)):
#
# ~\anaconda3\lib\site-packages\dask\dataframe\io\csv.py in coerce_dtypes(df, dtypes)
#     253             rule.join(filter(None, [dtype_msg, date_msg]))
#     254         )
# --> 255         raise ValueError(msg)
#     256
#     257
#
# ValueError: Mismatched dtypes found in `pd.read_csv`/`pd.read_table`.
#
# +--------------------------------------------------------+--------+----------+
# | Column                                                 | Found  | Expected |
# +--------------------------------------------------------+--------+----------+
# | Authorized Official Telephone Number                   | object | float64  |
# | Other Provider Identifier Issuer_30                    | object | float64  |
# | Other Provider Identifier Issuer_31                    | object | float64  |
# | Other Provider Identifier Issuer_32                    | object | float64  |
# | Other Provider Identifier Issuer_33                    | object | float64  |
# | Other Provider Identifier Issuer_34                    | object | float64  |
# | Other Provider Identifier Issuer_35                    | object | float64  |
# | Other Provider Identifier Issuer_36                    | object | float64  |
# | Other Provider Identifier Issuer_37                    | object | float64  |
# | Other Provider Identifier Issuer_39                    | object | float64  |
# | Other Provider Identifier Issuer_40                    | object | float64  |
# | Other Provider Identifier Issuer_41                    | object | float64  |
# | Other Provider Identifier Issuer_42                    | object | float64  |
# | Other Provider Identifier Issuer_43                    | object | float64  |
# | Other Provider Identifier Issuer_44                    | object | float64  |
# | Other Provider Identifier Issuer_45                    | object | float64  |
# | Other Provider Identifier Issuer_46                    | object | float64  |
# | Other Provider Identifier Issuer_47                    | object | float64  |
# | Other Provider Identifier Issuer_48                    | object | float64  |
# | Other Provider Identifier Issuer_49                    | object | float64  |
# | Other Provider Identifier State_48                     | object | float64  |
# | Other Provider Identifier_32                           | object | float64  |
# | Other Provider Identifier_33                           | object | float64  |
# | Other Provider Identifier_48                           | object | float64  |
# | Other Provider Identifier_49                           | object | float64  |
# | Provider Business Mailing Address Fax Number           | object | float64  |
# | Provider Business Practice Location Address Fax Number | object | float64  |
# +--------------------------------------------------------+--------+----------+
#
# The following columns also raised exceptions on conversion:
#
# - Authorized Official Telephone Number
#   ValueError("could not convert string to float: '703 752 6197'")
# - Other Provider Identifier Issuer_30
#   ValueError("could not convert string to float: 'AWARD: WORLD LAUREATE OF U.S.A. FOR PERSONAL ACHIEVEMENTS AND DEDICATION SOCIETY'")
# - Other Provider Identifier Issuer_31
#   ValueError("could not convert string to float: 'NATIONAL BOARD OF OSTEOPATHIC MEDICAL EXAMINERS-DIPLOMATE STATUS NATIONALLY'")
# - Other Provider Identifier Issuer_32
#   ValueError("could not convert string to float: 'AMERICAN OSTEOPATHIC BOARD OF FAMILY PHYSICIANS (AOBFP) OSTEOPATHIC MANIPULATION'")
# - Other Provider Identifier Issuer_33
#   ValueError("could not convert string to float: 'RECOGNITION OF APPRECIATION FOR HEALTH SERVICES: AMERICAN RED CROSS NE TORNADO'")
# - Other Provider Identifier Issuer_34
#   ValueError("could not convert string to float: 'DOCTORS OF THE WORLD'")
# - Other Provider Identifier Issuer_35
#   ValueError("could not convert string to float: 'PROFESSIONAL & COMPASSIONATE MEDICAL HEALTH CARE TO OUR AMERICAN VETERANS-US VA'")
# - Other Provider Identifier Issuer_36
#   ValueError("could not convert string to float: 'AWARD: KEY TO SUCCESS, MEDICAL EXCELLENCE'")
# - Other Provider Identifier Issuer_37
#   ValueError('could not convert string to float: "DAV DISABLED AMERICAN VETERANS\' COMMANDER\'S CLUB WALL OF HONOR"')
# - Other Provider Identifier Issuer_39
#   ValueError('could not convert string to float: "DEAN\'S LIST FOR OUTSTANDING ACADEMIC ACHIEVEMENT: KSU KENT STATE UNIVERSITY"')
# - Other Provider Identifier Issuer_40
#   ValueError("could not convert string to float: 'SOCIETY OF TEACHERS OF FAMILY MEDICINE (STFM)'")
# - Other Provider Identifier Issuer_41
#   ValueError("could not convert string to float: 'FLIGHT FOR LIFE, STAFF FLIGHT SURGEON-EMERGENCY HELICOPTER RESCUES'")
# - Other Provider Identifier Issuer_42
#   ValueError('could not convert string to float: "AWARD: LIFE MEMEBER, NATIONAL REGISTRY OF WHO\'S WHO"')
# - Other Provider Identifier Issuer_43
#   ValueError('could not convert string to float: "CONSUMERS\' RESEARCH COUNSIL OF AMERICA-AMERICA\'S TOP FAMILY PHYSICIANS"')
# - Other Provider Identifier Issuer_44
#   ValueError("could not convert string to float: 'AMERICAN OSTEOPATHIC BOARD OF FAMILY PHYSICIANS USA BOARD CERTIFICATIONS'")
# - Other Provider Identifier Issuer_45
#   ValueError("could not convert string to float: 'AMERICAN ACADEMY OF FAMILY PHYSICIANS (AAFP)'")
# - Other Provider Identifier Issuer_46
#   ValueError("could not convert string to float: 'CERTIFIED PHYSICIAN EXECUTIVE'")
# - Other Provider Identifier Issuer_47
#   ValueError("could not convert string to float: 'VICE PRESIDENT, CLEVELAND SOCIETY OF CLINICAL HYPNOSIS (C.S.C.H.)'")
# - Other Provider Identifier Issuer_48
#   ValueError("could not convert string to float: 'STATE OF OHIO MEDICAL LICENSE # 34-006816-R'")
# - Other Provider Identifier Issuer_49
#   ValueError("could not convert string to float: 'AWARD: KEY OF SUCCESS, PROFESSIONAL PERFORMANCE'")
# - Other Provider Identifier State_48
#   ValueError("could not convert string to float: 'OH'")
# - Other Provider Identifier_32
#   ValueError("could not convert string to float: '1598120-01'")
# - Other Provider Identifier_33
#   ValueError("could not convert string to float: '200061970A'")
# - Other Provider Identifier_48
#   ValueError("could not convert string to float: '34-006816-R'")
# - Other Provider Identifier_49
#   ValueError("could not convert string to float: 'ABI'")
# - Provider Business Mailing Address Fax Number
#   ValueError("could not convert string to float: '82-031-869-4791'")
# - Provider Business Practice Location Address Fax Number
#   ValueError("could not convert string to float: '011-822-7917-8110'")
#
# Usually this is due to dask's dtype inference failing, and
# *may* be fixed by specifying dtypes manually by adding:
#
# dtype={'Authorized Official Telephone Number': 'object',
#        'Other Provider Identifier Issuer_30': 'object',
#        'Other Provider Identifier Issuer_31': 'object',
#        'Other Provider Identifier Issuer_32': 'object',
#        'Other Provider Identifier Issuer_33': 'object',
#        'Other Provider Identifier Issuer_34': 'object',
#        'Other Provider Identifier Issuer_35': 'object',
#        'Other Provider Identifier Issuer_36': 'object',
#        'Other Provider Identifier Issuer_37': 'object',
#        'Other Provider Identifier Issuer_39': 'object',
#        'Other Provider Identifier Issuer_40': 'object',
#        'Other Provider Identifier Issuer_41': 'object',
#        'Other Provider Identifier Issuer_42': 'object',
#        'Other Provider Identifier Issuer_43': 'object',
#        'Other Provider Identifier Issuer_44': 'object',
#        'Other Provider Identifier Issuer_45': 'object',
#        'Other Provider Identifier Issuer_46': 'object',
#        'Other Provider Identifier Issuer_47': 'object',
#        'Other Provider Identifier Issuer_48': 'object',
#        'Other Provider Identifier Issuer_49': 'object',
#        'Other Provider Identifier State_48': 'object',
#        'Other Provider Identifier_32': 'object',
#        'Other Provider Identifier_33': 'object',
#        'Other Provider Identifier_48': 'object',
#        'Other Provider Identifier_49': 'object',
#        'Provider Business Mailing Address Fax Number': 'object',
#        'Provider Business Practice Location Address Fax Number': 'object'}
#
# to the call to `read_csv`/`read_table`.
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,72,75,78,79,80,81,82,83,84,85,86,151,226,230,234,238,242,246,250,254,258,262,266,267,270,319,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,72,79,80,81,82,83,84,85,86,151,165,226,227,230,231,234,238,242,246,250,254,258,262,266,319,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (79,80,81,82,83,84,85,86,147,319,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,80,81,84,85,135,226,227,230,231,234,235,238,242,246,250,254,258,262,266,267,270,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,72,80,83,84,85,86,151,226,230,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (72,80,81,84,85,151,165,226,227,230,231,234,255,319,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))

# %%
dfmelt_code.head()
# Out:
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,72,75,78,79,80,81,82,83,84,85,86,151,226,230,234,238,242,246,250,254,258,262,266,267,270,319,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (79,80,81,82,83,84,85,86,147,319,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,71,72,73,74,75,78,79,80,81,82,83,84,85,86,151,226,230,231,234,235,238,242,246,250,254,262,266,270,274,278,282,286,290,294,295,297,298,299,302,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,72,73,79,80,81,82,83,84,85,86,147,151,226,227,230,231,234,235,238,242,246,250,254,255,258,262,266,271,274,278,282,286,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,72,79,80,81,82,83,84,85,86,151,165,226,227,230,231,234,238,242,246,250,254,258,262,266,319,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,80,81,84,85,135,226,227,230,231,234,235,238,242,246,250,254,258,262,266,267,270,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (72,80,81,84,85,151,165,226,227,230,231,234,255,319,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-163-013f5bf34a87> in <module>
# ----> 1 dfmelt_code.head()
#
# ~\anaconda3\lib\site-packages\dask\dataframe\core.py in head(self, n, npartitions, compute)
#    1003             Whether to compute the result, default is True.
#    1004         """
# -> 1005         return self._head(n=n, npartitions=npartitions, compute=compute, safe=True)
#    1006
#    1007     def _head(self, n, npartitions, compute, safe):
#
# ~\anaconda3\lib\site-packages\dask\dataframe\core.py in _head(self, n, npartitions, compute, safe)
#    1036
#    1037         if compute:
# -> 1038             result = result.compute()
#    1039         return result
#    1040
#
# ~\anaconda3\lib\site-packages\dask\base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# ~\anaconda3\lib\site-packages\dask\base.py in compute(*args, **kwargs)
#     442         postcomputes.append(x.__dask_postcompute__())
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     446
#
# ~\anaconda3\lib\site-packages\dask\threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      74                 pools[thread][num_workers] = pool
#      75
# ---> 76     results = get_async(
#      77         pool.apply_async,
#      78         len(pool._pool),
#
# ~\anaconda3\lib\site-packages\dask\local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     484                         _execute_task(task, data)  # Re-execute locally
#     485                     else:
# --> 486                         raise_exception(exc, tb)
#     487                 res, worker_id = loads(res_info)
#     488                 state["cache"][key] = res
#
# ~\anaconda3\lib\site-packages\dask\local.py in reraise(exc, tb)
#     314     if exc.__traceback__ is not tb:
#     315         raise exc.with_traceback(tb)
# --> 316     raise exc
#     317
#     318
#
# ~\anaconda3\lib\site-packages\dask\local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     220     try:
#     221         task, data = loads(task_info)
# --> 222         result = _execute_task(task, data)
#     223         id = get_id()
#     224         result = dumps((result, id))
#
# ~\anaconda3\lib\site-packages\dask\core.py in _execute_task(arg, cache, dsk)
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# ~\anaconda3\lib\site-packages\dask\dataframe\io\csv.py in pandas_read_text(reader, b, header, kwargs, dtypes, columns, write_header, enforce, path)
#     149     df = reader(bio, **kwargs)
#     150     if dtypes:
# --> 151         coerce_dtypes(df, dtypes)
#     152
#     153     if enforce and columns and (list(df.columns) != list(columns)):
#
# ~\anaconda3\lib\site-packages\dask\dataframe\io\csv.py in coerce_dtypes(df, dtypes)
#     253             rule.join(filter(None, [dtype_msg, date_msg]))
#     254         )
# --> 255         raise ValueError(msg)
#     256
#     257
#
# ValueError: Mismatched dtypes found in `pd.read_csv`/`pd.read_table`.
#
# +--------------------------------------------------------+--------+----------+
# | Column                                                 | Found  | Expected |
# +--------------------------------------------------------+--------+----------+
# | Authorized Official Telephone Number                   | object | float64  |
# | Other Provider Identifier Issuer_30                    | object | float64  |
# | Other Provider Identifier Issuer_31                    | object | float64  |
# | Other Provider Identifier Issuer_32                    | object | float64  |
# | Other Provider Identifier Issuer_33                    | object | float64  |
# | Other Provider Identifier Issuer_34                    | object | float64  |
# | Other Provider Identifier Issuer_35                    | object | float64  |
# | Other Provider Identifier Issuer_36                    | object | float64  |
# | Other Provider Identifier Issuer_37                    | object | float64  |
# | Other Provider Identifier Issuer_38                    | object | float64  |
# | Other Provider Identifier Issuer_39                    | object | float64  |
# | Other Provider Identifier Issuer_40                    | object | float64  |
# | Other Provider Identifier Issuer_41                    | object | float64  |
# | Other Provider Identifier_41                           | object | float64  |
# | Provider Business Mailing Address Fax Number           | object | float64  |
# | Provider Business Practice Location Address Fax Number | object | float64  |
# +--------------------------------------------------------+--------+----------+
#
# The following columns also raised exceptions on conversion:
#
# - Authorized Official Telephone Number
#   ValueError("could not convert string to float: '011-862-8821'")
# - Other Provider Identifier Issuer_30
#   ValueError("could not convert string to float: 'CARESOURCE'")
# - Other Provider Identifier Issuer_31
#   ValueError("could not convert string to float: 'AETNA'")
# - Other Provider Identifier Issuer_32
#   ValueError("could not convert string to float: 'TRICARE'")
# - Other Provider Identifier Issuer_33
#   ValueError("could not convert string to float: 'FIRST HEALTH'")
# - Other Provider Identifier Issuer_34
#   ValueError("could not convert string to float: 'TPA'")
# - Other Provider Identifier Issuer_35
#   ValueError("could not convert string to float: 'BUCKEYE'")
# - Other Provider Identifier Issuer_36
#   ValueError("could not convert string to float: 'RAILROAD MEDICARE'")
# - Other Provider Identifier Issuer_37
#   ValueError("could not convert string to float: 'FLORIDA HEALTH CARE PLANS'")
# - Other Provider Identifier Issuer_38
#   ValueError("could not convert string to float: 'GOLDEN RULE'")
# - Other Provider Identifier Issuer_39
#   ValueError("could not convert string to float: 'STAR ADMINISTRATION SERVICES'")
# - Other Provider Identifier Issuer_40
#   ValueError("could not convert string to float: 'UNICARE'")
# - Other Provider Identifier Issuer_41
#   ValueError("could not convert string to float: 'APEX'")
# - Other Provider Identifier_41
#   ValueError("could not convert string to float: 'R52867'")
# - Provider Business Mailing Address Fax Number
#   ValueError("could not convert string to float: '49+6221-17-2941'")
# - Provider Business Practice Location Address Fax Number
#   ValueError("could not convert string to float: '49-6221-172570'")
#
# Usually this is due to dask's dtype inference failing, and
# *may* be fixed by specifying dtypes manually by adding:
#
# dtype={'Authorized Official Telephone Number': 'object',
#        'Other Provider Identifier Issuer_30': 'object',
#        'Other Provider Identifier Issuer_31': 'object',
#        'Other Provider Identifier Issuer_32': 'object',
#        'Other Provider Identifier Issuer_33': 'object',
#        'Other Provider Identifier Issuer_34': 'object',
#        'Other Provider Identifier Issuer_35': 'object',
#        'Other Provider Identifier Issuer_36': 'object',
#        'Other Provider Identifier Issuer_37': 'object',
#        'Other Provider Identifier Issuer_38': 'object',
#        'Other Provider Identifier Issuer_39': 'object',
#        'Other Provider Identifier Issuer_40': 'object',
#        'Other Provider Identifier Issuer_41': 'object',
#        'Other Provider Identifier_41': 'object',
#        'Provider Business Mailing Address Fax Number': 'object',
#        'Provider Business Practice Location Address Fax Number': 'object'}
#
# to the call to `read_csv`/`read_table`.
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,72,80,83,84,85,86,151,226,230,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))

# %%
dfmelt_code.head(5)
# Out:
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,71,72,73,74,75,78,79,80,81,82,83,84,85,86,151,226,230,231,234,235,238,242,246,250,254,262,266,270,274,278,282,286,290,294,295,297,298,299,302,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,80,81,84,85,135,226,227,230,231,234,235,238,242,246,250,254,258,262,266,267,270,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,72,79,80,81,82,83,84,85,86,151,165,226,227,230,231,234,238,242,246,250,254,258,262,266,319,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,72,73,79,80,81,82,83,84,85,86,147,151,226,227,230,231,234,235,238,242,246,250,254,255,258,262,266,271,274,278,282,286,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (79,80,81,82,83,84,85,86,147,319,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,72,75,78,79,80,81,82,83,84,85,86,151,226,230,234,238,242,246,250,254,258,262,266,267,270,319,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (72,80,81,84,85,151,165,226,227,230,231,234,255,319,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,72,80,83,84,85,86,151,226,230,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-151-2a9d2caecc4b> in <module>
# ----> 1 dfmelt_code.head(5)
#
# ~\anaconda3\lib\site-packages\dask\dataframe\core.py in head(self, n, npartitions, compute)
#    1003             Whether to compute the result, default is True.
#    1004         """
# -> 1005         return self._head(n=n, npartitions=npartitions, compute=compute, safe=True)
#    1006
#    1007     def _head(self, n, npartitions, compute, safe):
#
# ~\anaconda3\lib\site-packages\dask\dataframe\core.py in _head(self, n, npartitions, compute, safe)
#    1036
#    1037         if compute:
# -> 1038             result = result.compute()
#    1039         return result
#    1040
#
# ~\anaconda3\lib\site-packages\dask\base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# ~\anaconda3\lib\site-packages\dask\base.py in compute(*args, **kwargs)
#     442         postcomputes.append(x.__dask_postcompute__())
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     446
#
# ~\anaconda3\lib\site-packages\dask\threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      74                 pools[thread][num_workers] = pool
#      75
# ---> 76     results = get_async(
#      77         pool.apply_async,
#      78         len(pool._pool),
#
# ~\anaconda3\lib\site-packages\dask\local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     484                         _execute_task(task, data)  # Re-execute locally
#     485                     else:
# --> 486                         raise_exception(exc, tb)
#     487                 res, worker_id = loads(res_info)
#     488                 state["cache"][key] = res
#
# ~\anaconda3\lib\site-packages\dask\local.py in reraise(exc, tb)
#     314     if exc.__traceback__ is not tb:
#     315         raise exc.with_traceback(tb)
# --> 316     raise exc
#     317
#     318
#
# ~\anaconda3\lib\site-packages\dask\local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     220     try:
#     221         task, data = loads(task_info)
# --> 222         result = _execute_task(task, data)
#     223         id = get_id()
#     224         result = dumps((result, id))
#
# ~\anaconda3\lib\site-packages\dask\core.py in _execute_task(arg, cache, dsk)
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# ~\anaconda3\lib\site-packages\dask\dataframe\io\csv.py in pandas_read_text(reader, b, header, kwargs, dtypes, columns, write_header, enforce, path)
#     149     df = reader(bio, **kwargs)
#     150     if dtypes:
# --> 151         coerce_dtypes(df, dtypes)
#     152
#     153     if enforce and columns and (list(df.columns) != list(columns)):
#
# ~\anaconda3\lib\site-packages\dask\dataframe\io\csv.py in coerce_dtypes(df, dtypes)
#     253             rule.join(filter(None, [dtype_msg, date_msg]))
#     254         )
# --> 255         raise ValueError(msg)
#     256
#     257
#
# ValueError: Mismatched dtypes found in `pd.read_csv`/`pd.read_table`.
#
# +--------------------------------------------------------+--------+----------+
# | Column                                                 | Found  | Expected |
# +--------------------------------------------------------+--------+----------+
# | Authorized Official Telephone Number                   | object | float64  |
# | Other Provider Identifier Issuer_30                    | object | float64  |
# | Other Provider Identifier Issuer_31                    | object | float64  |
# | Other Provider Identifier Issuer_32                    | object | float64  |
# | Other Provider Identifier Issuer_33                    | object | float64  |
# | Other Provider Identifier Issuer_34                    | object | float64  |
# | Other Provider Identifier Issuer_35                    | object | float64  |
# | Other Provider Identifier Issuer_36                    | object | float64  |
# | Other Provider Identifier Issuer_37                    | object | float64  |
# | Other Provider Identifier Issuer_39                    | object | float64  |
# | Other Provider Identifier Issuer_40                    | object | float64  |
# | Other Provider Identifier Issuer_41                    | object | float64  |
# | Other Provider Identifier Issuer_42                    | object | float64  |
# | Other Provider Identifier Issuer_43                    | object | float64  |
# | Other Provider Identifier Issuer_44                    | object | float64  |
# | Other Provider Identifier Issuer_45                    | object | float64  |
# | Other Provider Identifier Issuer_46                    | object | float64  |
# | Other Provider Identifier Issuer_47                    | object | float64  |
# | Other Provider Identifier Issuer_48                    | object | float64  |
# | Other Provider Identifier Issuer_49                    | object | float64  |
# | Other Provider Identifier State_48                     | object | float64  |
# | Other Provider Identifier_32                           | object | float64  |
# | Other Provider Identifier_33                           | object | float64  |
# | Other Provider Identifier_48                           | object | float64  |
# | Other Provider Identifier_49                           | object | float64  |
# | Provider Business Mailing Address Fax Number           | object | float64  |
# | Provider Business Practice Location Address Fax Number | object | float64  |
# +--------------------------------------------------------+--------+----------+
#
# The following columns also raised exceptions on conversion:
#
# - Authorized Official Telephone Number
#   ValueError("could not convert string to float: '703 752 6197'")
# - Other Provider Identifier Issuer_30
#   ValueError("could not convert string to float: 'AWARD: WORLD LAUREATE OF U.S.A. FOR PERSONAL ACHIEVEMENTS AND DEDICATION SOCIETY'")
# - Other Provider Identifier Issuer_31
#   ValueError("could not convert string to float: 'NATIONAL BOARD OF OSTEOPATHIC MEDICAL EXAMINERS-DIPLOMATE STATUS NATIONALLY'")
# - Other Provider Identifier Issuer_32
#   ValueError("could not convert string to float: 'AMERICAN OSTEOPATHIC BOARD OF FAMILY PHYSICIANS (AOBFP) OSTEOPATHIC MANIPULATION'")
# - Other Provider Identifier Issuer_33
#   ValueError("could not convert string to float: 'RECOGNITION OF APPRECIATION FOR HEALTH SERVICES: AMERICAN RED CROSS NE TORNADO'")
# - Other Provider Identifier Issuer_34
#   ValueError("could not convert string to float: 'DOCTORS OF THE WORLD'")
# - Other Provider Identifier Issuer_35
#   ValueError("could not convert string to float: 'PROFESSIONAL & COMPASSIONATE MEDICAL HEALTH CARE TO OUR AMERICAN VETERANS-US VA'")
# - Other Provider Identifier Issuer_36
#   ValueError("could not convert string to float: 'AWARD: KEY TO SUCCESS, MEDICAL EXCELLENCE'")
# - Other Provider Identifier Issuer_37
#   ValueError('could not convert string to float: "DAV DISABLED AMERICAN VETERANS\' COMMANDER\'S CLUB WALL OF HONOR"')
# - Other Provider Identifier Issuer_39
#   ValueError('could not convert string to float: "DEAN\'S LIST FOR OUTSTANDING ACADEMIC ACHIEVEMENT: KSU KENT STATE UNIVERSITY"')
# - Other Provider Identifier Issuer_40
#   ValueError("could not convert string to float: 'SOCIETY OF TEACHERS OF FAMILY MEDICINE (STFM)'")
# - Other Provider Identifier Issuer_41
#   ValueError("could not convert string to float: 'FLIGHT FOR LIFE, STAFF FLIGHT SURGEON-EMERGENCY HELICOPTER RESCUES'")
# - Other Provider Identifier Issuer_42
#   ValueError('could not convert string to float: "AWARD: LIFE MEMEBER, NATIONAL REGISTRY OF WHO\'S WHO"')
# - Other Provider Identifier Issuer_43
#   ValueError('could not convert string to float: "CONSUMERS\' RESEARCH COUNSIL OF AMERICA-AMERICA\'S TOP FAMILY PHYSICIANS"')
# - Other Provider Identifier Issuer_44
#   ValueError("could not convert string to float: 'AMERICAN OSTEOPATHIC BOARD OF FAMILY PHYSICIANS USA BOARD CERTIFICATIONS'")
# - Other Provider Identifier Issuer_45
#   ValueError("could not convert string to float: 'AMERICAN ACADEMY OF FAMILY PHYSICIANS (AAFP)'")
# - Other Provider Identifier Issuer_46
#   ValueError("could not convert string to float: 'CERTIFIED PHYSICIAN EXECUTIVE'")
# - Other Provider Identifier Issuer_47
#   ValueError("could not convert string to float: 'VICE PRESIDENT, CLEVELAND SOCIETY OF CLINICAL HYPNOSIS (C.S.C.H.)'")
# - Other Provider Identifier Issuer_48
#   ValueError("could not convert string to float: 'STATE OF OHIO MEDICAL LICENSE # 34-006816-R'")
# - Other Provider Identifier Issuer_49
#   ValueError("could not convert string to float: 'AWARD: KEY OF SUCCESS, PROFESSIONAL PERFORMANCE'")
# - Other Provider Identifier State_48
#   ValueError("could not convert string to float: 'OH'")
# - Other Provider Identifier_32
#   ValueError("could not convert string to float: '1598120-01'")
# - Other Provider Identifier_33
#   ValueError("could not convert string to float: '200061970A'")
# - Other Provider Identifier_48
#   ValueError("could not convert string to float: '34-006816-R'")
# - Other Provider Identifier_49
#   ValueError("could not convert string to float: 'ABI'")
# - Provider Business Mailing Address Fax Number
#   ValueError("could not convert string to float: '82-031-869-4791'")
# - Provider Business Practice Location Address Fax Number
#   ValueError("could not convert string to float: '011-822-7917-8110'")
#
# Usually this is due to dask's dtype inference failing, and
# *may* be fixed by specifying dtypes manually by adding:
#
# dtype={'Authorized Official Telephone Number': 'object',
#        'Other Provider Identifier Issuer_30': 'object',
#        'Other Provider Identifier Issuer_31': 'object',
#        'Other Provider Identifier Issuer_32': 'object',
#        'Other Provider Identifier Issuer_33': 'object',
#        'Other Provider Identifier Issuer_34': 'object',
#        'Other Provider Identifier Issuer_35': 'object',
#        'Other Provider Identifier Issuer_36': 'object',
#        'Other Provider Identifier Issuer_37': 'object',
#        'Other Provider Identifier Issuer_39': 'object',
#        'Other Provider Identifier Issuer_40': 'object',
#        'Other Provider Identifier Issuer_41': 'object',
#        'Other Provider Identifier Issuer_42': 'object',
#        'Other Provider Identifier Issuer_43': 'object',
#        'Other Provider Identifier Issuer_44': 'object',
#        'Other Provider Identifier Issuer_45': 'object',
#        'Other Provider Identifier Issuer_46': 'object',
#        'Other Provider Identifier Issuer_47': 'object',
#        'Other Provider Identifier Issuer_48': 'object',
#        'Other Provider Identifier Issuer_49': 'object',
#        'Other Provider Identifier State_48': 'object',
#        'Other Provider Identifier_32': 'object',
#        'Other Provider Identifier_33': 'object',
#        'Other Provider Identifier_48': 'object',
#        'Other Provider Identifier_49': 'object',
#        'Provider Business Mailing Address Fax Number': 'object',
#        'Provider Business Practice Location Address Fax Number': 'object'}
#
# to the call to `read_csv`/`read_table`.

# %%
npidata = npidata.merge(
    dfmelt_code,
    how='left',
    on='NPI'
)

# %%
dfmelt_code.head(5)
# Out:
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (79,80,81,82,83,84,85,86,147,319,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,72,79,80,81,82,83,84,85,86,151,165,226,227,230,231,234,238,242,246,250,254,258,262,266,319,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,71,72,73,74,75,78,79,80,81,82,83,84,85,86,151,226,230,231,234,235,238,242,246,250,254,262,266,270,274,278,282,286,290,294,295,297,298,299,302,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (72,80,81,84,85,151,165,226,227,230,231,234,255,319,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,72,73,79,80,81,82,83,84,85,86,147,151,226,227,230,231,234,235,238,242,246,250,254,255,258,262,266,271,274,278,282,286,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,72,75,78,79,80,81,82,83,84,85,86,151,226,230,234,238,242,246,250,254,258,262,266,267,270,319,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,80,81,84,85,135,226,227,230,231,234,235,238,242,246,250,254,258,262,266,267,270,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-2a9d2caecc4b> in <module>
# ----> 1 dfmelt_code.head(5)
#
# ~\anaconda3\lib\site-packages\dask\dataframe\core.py in head(self, n, npartitions, compute)
#    1003             Whether to compute the result, default is True.
#    1004         """
# -> 1005         return self._head(n=n, npartitions=npartitions, compute=compute, safe=True)
#    1006
#    1007     def _head(self, n, npartitions, compute, safe):
#
# ~\anaconda3\lib\site-packages\dask\dataframe\core.py in _head(self, n, npartitions, compute, safe)
#    1036
#    1037         if compute:
# -> 1038             result = result.compute()
#    1039         return result
#    1040
#
# ~\anaconda3\lib\site-packages\dask\base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# ~\anaconda3\lib\site-packages\dask\base.py in compute(*args, **kwargs)
#     442         postcomputes.append(x.__dask_postcompute__())
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     446
#
# ~\anaconda3\lib\site-packages\dask\threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      74                 pools[thread][num_workers] = pool
#      75
# ---> 76     results = get_async(
#      77         pool.apply_async,
#      78         len(pool._pool),
#
# ~\anaconda3\lib\site-packages\dask\local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     484                         _execute_task(task, data)  # Re-execute locally
#     485                     else:
# --> 486                         raise_exception(exc, tb)
#     487                 res, worker_id = loads(res_info)
#     488                 state["cache"][key] = res
#
# ~\anaconda3\lib\site-packages\dask\local.py in reraise(exc, tb)
#     314     if exc.__traceback__ is not tb:
#     315         raise exc.with_traceback(tb)
# --> 316     raise exc
#     317
#     318
#
# ~\anaconda3\lib\site-packages\dask\local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     220     try:
#     221         task, data = loads(task_info)
# --> 222         result = _execute_task(task, data)
#     223         id = get_id()
#     224         result = dumps((result, id))
#
# ~\anaconda3\lib\site-packages\dask\core.py in _execute_task(arg, cache, dsk)
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# ~\anaconda3\lib\site-packages\dask\dataframe\io\csv.py in pandas_read_text(reader, b, header, kwargs, dtypes, columns, write_header, enforce, path)
#     149     df = reader(bio, **kwargs)
#     150     if dtypes:
# --> 151         coerce_dtypes(df, dtypes)
#     152
#     153     if enforce and columns and (list(df.columns) != list(columns)):
#
# ~\anaconda3\lib\site-packages\dask\dataframe\io\csv.py in coerce_dtypes(df, dtypes)
#     253             rule.join(filter(None, [dtype_msg, date_msg]))
#     254         )
# --> 255         raise ValueError(msg)
#     256
#     257
#
# ValueError: Mismatched dtypes found in `pd.read_csv`/`pd.read_table`.
#
# +--------------------------------------------------------+--------+----------+
# | Column                                                 | Found  | Expected |
# +--------------------------------------------------------+--------+----------+
# | Other Provider Identifier Issuer_30                    | object | float64  |
# | Other Provider Identifier Issuer_31                    | object | float64  |
# | Other Provider Identifier Issuer_32                    | object | float64  |
# | Other Provider Identifier Issuer_33                    | object | float64  |
# | Other Provider Identifier Issuer_34                    | object | float64  |
# | Other Provider Identifier Issuer_35                    | object | float64  |
# | Other Provider Identifier Issuer_36                    | object | float64  |
# | Other Provider Identifier Issuer_37                    | object | float64  |
# | Other Provider Identifier Issuer_38                    | object | float64  |
# | Other Provider Identifier Issuer_39                    | object | float64  |
# | Other Provider Identifier Issuer_40                    | object | float64  |
# | Other Provider Identifier_31                           | object | float64  |
# | Other Provider Identifier_32                           | object | float64  |
# | Provider Business Mailing Address Fax Number           | object | float64  |
# | Provider Business Practice Location Address Fax Number | object | float64  |
# +--------------------------------------------------------+--------+----------+
#
# The following columns also raised exceptions on conversion:
#
# - Other Provider Identifier Issuer_30
#   ValueError("could not convert string to float: 'LICENSE'")
# - Other Provider Identifier Issuer_31
#   ValueError("could not convert string to float: 'ADVANTICA EYECARE'")
# - Other Provider Identifier Issuer_32
#   ValueError("could not convert string to float: 'AMERICAN REPUBLIC'")
# - Other Provider Identifier Issuer_33
#   ValueError("could not convert string to float: 'PIRELLI ARMSTRONG'")
# - Other Provider Identifier Issuer_34
#   ValueError("could not convert string to float: 'AMERICARE'")
# - Other Provider Identifier Issuer_35
#   ValueError("could not convert string to float: 'MIDLANDS CHOICE'")
# - Other Provider Identifier Issuer_36
#   ValueError("could not convert string to float: 'ACCOUNTABLE HEALTH'")
# - Other Provider Identifier Issuer_37
#   ValueError("could not convert string to float: 'WELLMARK BLUE SHIELD'")
# - Other Provider Identifier Issuer_38
#   ValueError("could not convert string to float: 'GLACERS LOCAL #558'")
# - Other Provider Identifier Issuer_39
#   ValueError("could not convert string to float: 'UNITED AMERICAN INSURANCE COMPANY'")
# - Other Provider Identifier Issuer_40
#   ValueError("could not convert string to float: 'COVENTRY ADVANTRA'")
# - Other Provider Identifier_31
#   ValueError("could not convert string to float: 'XHSP42759'")
# - Other Provider Identifier_32
#   ValueError("could not convert string to float: 'OEG001239'")
# - Provider Business Mailing Address Fax Number
#   ValueError("could not convert string to float: '000226-8802'")
# - Provider Business Practice Location Address Fax Number
#   ValueError("could not convert string to float: '000226-8802'")
#
# Usually this is due to dask's dtype inference failing, and
# *may* be fixed by specifying dtypes manually by adding:
#
# dtype={'Other Provider Identifier Issuer_30': 'object',
#        'Other Provider Identifier Issuer_31': 'object',
#        'Other Provider Identifier Issuer_32': 'object',
#        'Other Provider Identifier Issuer_33': 'object',
#        'Other Provider Identifier Issuer_34': 'object',
#        'Other Provider Identifier Issuer_35': 'object',
#        'Other Provider Identifier Issuer_36': 'object',
#        'Other Provider Identifier Issuer_37': 'object',
#        'Other Provider Identifier Issuer_38': 'object',
#        'Other Provider Identifier Issuer_39': 'object',
#        'Other Provider Identifier Issuer_40': 'object',
#        'Other Provider Identifier_31': 'object',
#        'Other Provider Identifier_32': 'object',
#        'Provider Business Mailing Address Fax Number': 'object',
#        'Provider Business Practice Location Address Fax Number': 'object'}
#
# to the call to `read_csv`/`read_table`.
# C:\Users\matth\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (27,35,40,46,72,80,83,84,85,86,151,226,230,320,321,322,323) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))

# %%
# Pivot from widet to long format
npi_taxonomy = pd.wide_to_long(
    npi_taxonomy,
    stubnames=['Healthcare Provider Taxonomy Code', 'Healthcare Provider Primary Taxonomy Switch'],
    i=['NPI'], 
    j='primary_taxonomy_index',
    sep="_"
)

# Only keep the primary taxonomy
npi_taxonomy = npi_taxonomy[npi_taxonomy['Healthcare Provider Primary Taxonomy Switch'] == 'Y']

# Housekeeping
npi_taxonomy = npi_taxonomy.reset_index()\
    .drop(columns=['primary_taxonomy_index', 'Healthcare Provider Primary Taxonomy Switch'])\
    .rename({ 'Healthcare Provider Taxonomy Code': 'primary_taxonomy' }, axis=1)

npi_taxonomy
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-e6fa4ec36d89> in <module>
#       1 # Pivot from widet to long format
# ----> 2 npi_taxonomy = pd.wide_to_long(
#       3     npi_taxonomy,
#       4     stubnames=['Healthcare Provider Taxonomy Code', 'Healthcare Provider Primary Taxonomy Switch'],
#       5     i=['NPI'],
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\melt.py in wide_to_long(df, stubnames, i, j, sep, suffix)
#     455         i = list(i)
#     456
# --> 457     if df[i].duplicated().any():
#     458         raise ValueError("the id variables need to uniquely identify each row")
#     459
#
# ~\anaconda3\lib\site-packages\dask\dataframe\core.py in __getattr__(self, key)
#    3586             return self[key]
#    3587         else:
# -> 3588             raise AttributeError("'DataFrame' object has no attribute %r" % key)
#    3589
#    3590     def __dir__(self):
#
# AttributeError: 'DataFrame' object has no attribute 'duplicated'

# %%
# Only keep the primary taxonomy
npi_taxonomy = npi_taxonomy[npi_taxonomy['Healthcare Provider Primary Taxonomy Switch'] == 'Y']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# KeyError: 'Healthcare Provider Primary Taxonomy Switch'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-91d22c02fb96> in <module>
#       1 # Only keep the primary taxonomy
# ----> 2 npi_taxonomy = npi_taxonomy[npi_taxonomy['Healthcare Provider Primary Taxonomy Switch'] == 'Y']
#
# ~\anaconda3\lib\site-packages\dask\dataframe\core.py in __getitem__(self, key)
#    3512
#    3513             # error is raised from pandas
# -> 3514             meta = self._meta[_extract_meta(key)]
#    3515             dsk = partitionwise_graph(operator.getitem, name, self, key)
#    3516             graph = HighLevelGraph.from_collections(name, dsk, dependencies=[self])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# KeyError: 'Healthcare Provider Primary Taxonomy Switch'

# %%
npi_taxonomy.melt(id_vars=['NPI'], var_name='primary_taxonomy_index')
# Out:
# Dask DataFrame Structure:
#                    NPI primary_taxonomy_index   value
# npartitions=126
#                  int64                 object  object
#                    ...                    ...     ...
# ...                ...                    ...     ...
#                    ...                    ...     ...
#                    ...                    ...     ...
# Dask Name: melt, 378 tasks
